# %% [markdown]
# ### ニューラルネットワーク

# %% [markdown]
# ニューラルネットワークスクラッチの検証にはMNISTデータセットを使用します。各種ライブラリやサイトからダウンロードできますが、ここでは深層学習フレームワークのKerasを用います。以下のコードを実行すればデータセットをダウンロードし、展開まで行えます。

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import math
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import statistics
from scipy import stats
import collections
import random
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import KFold

# %%
import keras
from keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %% [markdown]
# 《MNISTとは？》
#
# 画像分類のための定番データセットで、手書き数字認識を行います。このデータセットには訓練用6万枚、テスト用1万枚の28×28ピクセルの白黒画像、およびそれらが0〜9のどの数字であるかというラベルが含まれています。
#
#
# 《画像データとは？》
#
# デジタル画像は点の集合で、これをピクセルと呼びます。一般的に白黒画像であればピクセルには0〜255の値が含まれます。一方、カラー画像であればR（赤）、G（緑）、B（青）それぞれに対応する0〜255の値が含まれます。機械学習をする上では、この0〜255の値一つひとつが特徴量として扱われます。0〜255は符号なしの8ビット整数で表せる範囲になるため、NumPyであれば「uint8」型の変数として保持できます。
#
# 平滑化
#
# (1, 28, 28)の各画像を、(1, 784)に変換します。これまで学んできた機械学習手法や、今回扱う全結合層のみのニューラルネットワークではこの形で扱います。全てのピクセルが一列になっていることを、 平滑化（flatten） してあるという風に表現します。

# %%
# データを平滑化する。
X_train = X_train.reshape(-1, 784)
X_test = X_test.reshape(-1, 784)

# %% [markdown]
# #### 画像データの可視化
#
# 画像データを可視化します。plt.imshowに渡します。

# %%
index = 0
image = X_train[index].reshape(28,28)
# X_train[index]: (784,)
# image: (28, 28)
plt.imshow(image, 'gray')
plt.title('label : {}'.format(y_train[index]))
plt.show()

# %% [markdown]
# 《発展的話題》
#
# 画像データは符号なし8ビット整数のuint8型で保持されることが一般的ですが、plt.imshowはより自由な配列を画像として表示することが可能です。例えば、以下のようにマイナスの値を持ったfloat64型の浮動小数点であってもエラーにはならないし、先ほどと全く同じ風に表示されます。

# %%
index = 0
image = X_train[index].reshape(28,28)
image = image.astype(np.float) # float型に変換
image -= 105.35 # 意図的に負の小数値を作り出してみる
plt.imshow(image, 'gray')
plt.title('label : {}'.format(y_train[index]))
plt.show()
print(image) # 値を確認
# Out:
# [[-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -102.35  -87.35  -87.35  -87.35   20.65   30.65
#     69.65  -79.35   60.65  149.65  141.65   21.65 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35  -75.35
#    -69.35  -11.35   48.65   64.65  147.65  147.65  147.65  147.65  147.65
#    119.65   66.65  147.65  136.65   89.65  -41.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35  -56.35  132.65
#    147.65  147.65  147.65  147.65  147.65  147.65  147.65  147.65  145.65
#    -12.35  -23.35  -23.35  -49.35  -66.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35  -87.35  113.65
#    147.65  147.65  147.65  147.65  147.65   92.65   76.65  141.65  135.65
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35  -25.35
#     50.65    1.65  147.65  147.65   99.65  -94.35 -105.35  -62.35   48.65
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#    -91.35 -104.35   48.65  147.65  -15.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35   33.65  147.65   84.65 -103.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35  -94.35   84.65  147.65  -35.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35  -70.35  135.65  119.65   54.65    2.65 -104.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35  -24.35  134.65  147.65  147.65   13.65
#    -80.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35  -60.35   80.65  147.65  147.65
#     44.65  -78.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35  -89.35  -12.35  146.65
#    147.65   81.65 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35  143.65
#    147.65  143.65  -41.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35  -59.35   24.65   77.65  147.65
#    147.65  101.65 -103.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35  -66.35   42.65  123.65  147.65  147.65  147.65
#    144.65   76.65 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35  -81.35    8.65  115.65  147.65  147.65  147.65  147.65   95.65
#    -27.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35  -82.35
#    -39.35  107.65  147.65  147.65  147.65  147.65   92.65  -24.35 -103.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35  -87.35   65.65  113.65
#    147.65  147.65  147.65  147.65   89.65  -25.35  -96.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35  -50.35   66.65  120.65  147.65  147.65
#    147.65  147.65  138.65   27.65  -94.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35   30.65  147.65  147.65  147.65  106.65
#     29.65   26.65  -89.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]
#  [-105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35 -105.35
#   -105.35]]

# %% [markdown]
# これは、自動的に値を0〜255の整数に変換して処理するように作られているからです。uint8型であっても最小値が0、最大値が255でない場合には色合いがおかしくなります。それを防ぐためには次のように引数を入れてください。
#
# plt.imshow(image, 'gray', vmin = 0, vmax = 255)
#
# 画像関係のライブラリではこの自動的なスケーリングが思わぬ結果を生むことがあるので、新しいメソッドを使うときには確認しておきましょう。

# %% [markdown]
# #### 前処理
# 画像は0から255のuint8型で表されますが、機械学習をする上では0から1のfloat型で扱うことになります。以下のコードで変換可能です。

# %%
X_train = X_train.astype(np.float)
X_test = X_test.astype(np.float)
X_train /= 255
X_test /= 255

# %% [markdown]
# また、正解ラベルは0から9の整数ですが、ニューラルネットワークで多クラス分類を行う際には one-hot表現 に変換します。scikit-learnのOneHotEncoderを使用したコードが以下です。このone-hot表現による値はそのラベルである確率を示していることになるため、float型で扱います。

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore', sparse=False)
y_train_one_hot = enc.fit_transform(y_train[:, np.newaxis])
y_test_one_hot = enc.transform(y_test[:, np.newaxis])
print(y_train.shape) # (60000,)
print(y_train_one_hot.shape) # (60000, 10)
print(y_train_one_hot.dtype) # float64
# Out:
# (60000,)
# (60000, 10)
# float64

# %% [markdown]
# さらに、訓練データ6万枚の内2割を検証データとして分割してください。訓練データが48000枚、検証データが12000枚となります。

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train_one_hot, test_size=0.2)
print(X_train.shape) # (48000, 784)
print(X_val.shape) # (12000, 784)
# Out:
# (48000, 784)
# (12000, 784)

# %% [markdown]
# ### ミニバッチ処理
#
#
# これまでの機械学習スクラッチでは、全てのサンプルを一度に計算していました。しかし、ニューラルネットワークではデータを分割して入力する 確率的勾配降下法 が一般的です。分割した際のひとかたまりを ミニバッチ 、そのサンプル数を バッチサイズ と呼びます。
#
#
# 今回はバッチサイズを20とします。今回使う訓練データは48000枚ですから、48000÷20で2400回の更新を繰り返すことになります。ニューラルネットワークではこれを2400回 イテレーション（iteration） すると呼びます。訓練データを一度全て見ると1回の エポック（epoch） が終わったことになります。このエポックを複数回繰り返し、学習が完了します。
#
#
# これを実現するための簡素なイテレータを用意しました。for文で呼び出すと、ミニバッチを取得できます。

# %%
class GetMiniBatch:
    """
    ミニバッチを取得するイテレータ

    Parameters
    ----------
    X : 次の形のndarray, shape (n_samples, n_features)
      訓練データ
    y : 次の形のndarray, shape (n_samples, 1)
      正解値
    batch_size : int
      バッチサイズ
    seed : int
      NumPyの乱数のシード
    """
    def __init__(self, X, y, batch_size = 20, seed=0):
        self.batch_size = batch_size
        np.random.seed(seed)
        shuffle_index = np.random.permutation(np.arange(X.shape[0]))
        self._X = X[shuffle_index]
        self._y = y[shuffle_index]
        self._stop = np.ceil(X.shape[0]/self.batch_size).astype(np.int)
    def __len__(self):
        return self._stop
    
    def __getitem__(self,item):
        p0 = item*self.batch_size
        p1 = item*self.batch_size + self.batch_size
        return self._X[p0:p1], self._y[p0:p1]        
    def __iter__(self):
        self._counter = 0
        return self
    def __next__(self):
        if self._counter >= self._stop:
            raise StopIteration()
        p0 = self._counter*self.batch_size
        p1 = self._counter*self.batch_size + self.batch_size
        self._counter += 1
        return self._X[p0:p1], self._y[p0:p1]

# %% [markdown]
# ### ニューラルネットワークスクラッチ
#
# ニューラルネットワークのクラスをスクラッチで作成していきます。NumPyなど最低限のライブラリのみを使いアルゴリズムを実装していきます。
#
#
# 今回は多クラス分類を行う3層のニューラルネットワークを作成します。層の数などは固定した上でニューラルネットワークの基本を学びます。次のSprintで層を自由に変えられる設計にしていきます。
#
#
# 以下に雛形を用意してあります。このScratchSimpleNeuralNetrowkClassifierクラスにコードを書き加えていってください。

# %%
class ScratchSimpleNeuralNetrowkClassifier():
    """
    シンプルな三層ニューラルネットワーク分類器

    Parameters
    ----------

    Attributes
    ----------
    """
    
    def __init__(self, verbose = True):
        self.verbose = verbose
        self.L_log = []
        self.L_val_log = []
        batch_size = 80
        n_features = 784
        n_nodes1 = 400
        n_nodes2 = 200
        n_output = 10

        sigma = 0.01 # ガウス分布の標準偏差

        self.W1 = sigma * np.random.randn(n_features, n_nodes1) # 第1層目の重み　（係数）
        self.W2 = sigma * np.random.randn(n_nodes1, n_nodes2) # 第2層目の重み（係数）
        self.W3 = sigma * np.random.randn(n_nodes2, n_output) # 第3層目の重み　（係数）
        self.B1 = sigma * np.random.randn(n_nodes1) # 第1層目の重み　（バイアス）
        self.B2 = sigma * np.random.randn(n_nodes2) # 第2層目の重み　（バイアス）
        self.B3 = sigma * np.random.randn(n_output) # 第3層目の重み　（バイアス）
    
    def fit(self, X, y, X_val=None, y_val=None, rate=0.01, epoch=2):
        
        """
        ニューラルネットワーク分類器を学習する。

        Parameters
        ----------
        X : 次の形のndarray, shape (n_samples, n_features)
            訓練データの特徴量
        y : 次の形のndarray, shape (n_samples, )
            訓練データの正解値
        X_val : 次の形のndarray, shape (n_samples, n_features)
            検証データの特徴量
        y_val : 次の形のndarray, shape (n_samples, )
            検証データの正解値
            """
        self.rate = rate
        self.X = X
        self.y = y # yはすでにone-hot済の正解ラベル
        
        iteration = 600 #訓練データ48000枚 / バッチサイズ80(20から変更)
        
        for i in range(epoch):
            get_mini_batch = GetMiniBatch(X, y, batch_size=80) # ミニバッチ生成関数のインスタンス生成
            K = 0
            for self.X, self.y in get_mini_batch: # ミニバッチ単位でフォーワード、バックプロパの学習をイテレーション分繰り返す。
                self.forward()
                self.backpro()
                K += 1
                if self.verbose:
                    Z3 = self.predict(self.X)[1] # 学習結果元にトレインデータの予測
                    L = self.entropy(Z3,self.y)  # トレインデータのエントロピー計算
                    self.L_log.append(L)         # エントロピー結果を記録しておく
                    print("(train) iter数 ： {} => cross entropy : {}".format(K,L))
                if X_val is not None:
                    index = random.sample(range(len(X_val)), k=80)
                    Z3_val = self.predict(X_val[index])[1]          # 学習結果元にvalデータの予測
                    L_val = self.entropy(Z3_val,y_val[index])  # valデータのエントロピー計算
                    self.L_val_log.append(L_val)        # エントロピー結果を記録しておく
                    print("  (val) iter数 ： {} => cross entropy : {}".format(K,L_val))
                      
    def predict(self, X):   # これまで学習したW1〜3, B1〜3,を使いフォーワードで入力から出力（確率が最も高いラベル）を計算
        # 1層目
        A1 = X @ self.W1 + self.B1          
        Z1 = self.activation(A1,"sigmoid")
        
        # 2層目
        A2 = Z1 @ self.W2 + self.B2
        Z2 = self.activation(A2,"sigmoid")
        
        # 3層目
        A3 = Z2 @ self.W3 + self.B3
        Z3 = self.softmax(A3)
        
        return np.argmax(Z3, axis=1) , Z3           
    
    def forward(self):    # フォーワードで入力から出力（確率が最も高いラベル）を計算する。
        
        # 1層目
        self.A1 = self.X @ self.W1 + self.B1
        self.Z1 = self.activation(self.A1,"sigmoid")
        
        # 2層目
        self.A2 = self.Z1 @ self.W2 + self.B2
        self.Z2 = self.activation(self.A2,"sigmoid")
        
        # 3層目
        self.A3 = self.Z2 @ self.W3 + self.B3
        self.Z3 = self.softmax(self.A3)
        
    def backpro(self):  # フォーワードで求まった出力（予測値）を元に誤差を出し、そこから、逆伝搬で各層の重みの偏微分を算出し勾配降下で重みを更新
        
        # 3層目
        grad_A3 = self.Z3 - self.y
        grad_B3 = np.sum(grad_A3, axis=0)
        grad_W3 = self.Z2.T @ grad_A3
        grad_Z2 = grad_A3 @ self.W3.T
        
        # 2層目
        grad_A2 = grad_Z2 * (1-np.tanh(self.A2)**2)
        grad_B2 = np.sum(grad_A2, axis=0)
        grad_W2 = self.Z1.T @ grad_A2
        grad_Z1 = grad_A2 @ self.W2.T
        
        # 1層目
        grad_A1 = grad_Z1 * (1-np.tanh(self.A1)**2)
        grad_B1 = np.sum(grad_A1, axis=0)
        grad_W1 = self.X.T @ grad_A1
        
        # 上記計算結果を元に各層の重み（係数W,バイアスB）を更新
        self.W1 -= self.rate * grad_W1
        self.B1 -= self.rate * grad_B1
        self.W2 -= self.rate * grad_W2
        self.B2 -= self.rate * grad_B2
        self.W3 -= self.rate * grad_W3
        self.B3 -= self.rate * grad_B3
        
    
    def entropy(self,Z3, y_one_hot_label):  # 各ラベルの予測確率と正解ラベル（onehot）を引数にクロスエントロピを計算。その際、バッチ単位で平均したものを出力
        batch_size = len(Z3)
        L = -1/batch_size*np.sum(y_one_hot_label*np.log(Z3))
        return L
    
    def activation(self, A, model): # 使用する活性化関数を関数化しておく。
        if model == "sigmoid" :
            return 1/(1+np.exp(-A))
        
        if model == "tanh" :
            return np.tanh(A)
    
    def softmax(self,A3):       # 使用するソフトマックス関数を関数化しておく
        batch_size = len(A3)
        output = 10
        Z3 = np.zeros((batch_size,output))
        for i in range(batch_size):
            for k in range (output):
                Z3[i][k] = np.exp(A3)[i][k]/np.sum(np.exp(A3), axis=1)[i]
        return Z3

# %%
model1 = ScratchSimpleNeuralNetrowkClassifier()
model1.fit(X_train, y_train, X_val, y_val)
# Out:
# (train) iter数 ： 1 => cross entropy : 2.369409516212136
#   (val) iter数 ： 1 => cross entropy : 2.4048887582627083
# (train) iter数 ： 2 => cross entropy : 2.8901129668866137
#   (val) iter数 ： 2 => cross entropy : 3.424380806902987
# (train) iter数 ： 3 => cross entropy : 2.49150913475075
#   (val) iter数 ： 3 => cross entropy : 2.8218648311896715
# (train) iter数 ： 4 => cross entropy : 2.306082164212729
#   (val) iter数 ： 4 => cross entropy : 2.3829798138531224
# (train) iter数 ： 5 => cross entropy : 2.3182175769546083
#   (val) iter数 ： 5 => cross entropy : 2.303272652038395
# (train) iter数 ： 6 => cross entropy : 2.3015250884069363
#   (val) iter数 ： 6 => cross entropy : 2.3103982737484308
# (train) iter数 ： 7 => cross entropy : 2.3013573404184995
#   (val) iter数 ： 7 => cross entropy : 2.3031039885889757
# (train) iter数 ： 8 => cross entropy : 2.2949753143641525
#   (val) iter数 ： 8 => cross entropy : 2.304392976217762
# (train) iter数 ： 9 => cross entropy : 2.1907009390210024
#   (val) iter数 ： 9 => cross entropy : 2.3399479025030407
# (train) iter数 ： 10 => cross entropy : 2.275113343037383
#   (val) iter数 ： 10 => cross entropy : 2.3098548353484745
# (train) iter数 ： 11 => cross entropy : 2.280177589841243
#   (val) iter数 ： 11 => cross entropy : 2.2895384547518898
# (train) iter数 ： 12 => cross entropy : 2.2496722705538335
#   (val) iter数 ： 12 => cross entropy : 2.271713486103847
# (train) iter数 ： 13 => cross entropy : 2.294399986823805
#   (val) iter数 ： 13 => cross entropy : 2.3212421938171466
# (train) iter数 ： 14 => cross entropy : 2.294054044039487
#   (val) iter数 ： 14 => cross entropy : 2.301193381627806
# (train) iter数 ： 15 => cross entropy : 2.2766929887950966
#   (val) iter数 ： 15 => cross entropy : 2.3174092993399618
# (train) iter数 ： 16 => cross entropy : 2.285407914199136
#   (val) iter数 ： 16 => cross entropy : 2.31288969013364
# (train) iter数 ： 17 => cross entropy : 2.261493413484574
#   (val) iter数 ： 17 => cross entropy : 2.306418570456306
# (train) iter数 ： 18 => cross entropy : 2.2735907955801884
#   (val) iter数 ： 18 => cross entropy : 2.3108893884739325
# (train) iter数 ： 19 => cross entropy : 2.269924565506655
#   (val) iter数 ： 19 => cross entropy : 2.2919547031454335
# (train) iter数 ： 20 => cross entropy : 2.2677899921252562
#   (val) iter数 ： 20 => cross entropy : 2.3118275182533377
# (train) iter数 ： 21 => cross entropy : 2.2841918909042023
#   (val) iter数 ： 21 => cross entropy : 2.307040026049674
# (train) iter数 ： 22 => cross entropy : 2.259286182617912
#   (val) iter数 ： 22 => cross entropy : 2.3399413128854722
# (train) iter数 ： 23 => cross entropy : 2.296413506468194
#   (val) iter数 ： 23 => cross entropy : 2.288848342403556
# (train) iter数 ： 24 => cross entropy : 2.2404207730574215
#   (val) iter数 ： 24 => cross entropy : 2.2873123385090603
# (train) iter数 ： 25 => cross entropy : 2.284294935075105
#   (val) iter数 ： 25 => cross entropy : 2.3193128888070116
# (train) iter数 ： 26 => cross entropy : 2.297596779259912
#   (val) iter数 ： 26 => cross entropy : 2.288314032223861
# (train) iter数 ： 27 => cross entropy : 2.2681657027188415
#   (val) iter数 ： 27 => cross entropy : 2.3086428666150236
# (train) iter数 ： 28 => cross entropy : 2.242526524607532
#   (val) iter数 ： 28 => cross entropy : 2.325452386867154
# (train) iter数 ： 29 => cross entropy : 2.274033043490204
#   (val) iter数 ： 29 => cross entropy : 2.3160162232957187
# (train) iter数 ： 30 => cross entropy : 2.2409087559001994
#   (val) iter数 ： 30 => cross entropy : 2.3691002622386237
# (train) iter数 ： 31 => cross entropy : 2.2756099482674363
#   (val) iter数 ： 31 => cross entropy : 2.3176874857941065
# (train) iter数 ： 32 => cross entropy : 2.2993691482794425
#   (val) iter数 ： 32 => cross entropy : 2.2853550398246365
# (train) iter数 ： 33 => cross entropy : 2.272255284944246
#   (val) iter数 ： 33 => cross entropy : 2.305315725266952
# (train) iter数 ： 34 => cross entropy : 2.264955342363966
#   (val) iter数 ： 34 => cross entropy : 2.3033337892697525
# (train) iter数 ： 35 => cross entropy : 2.2776334228621304
#   (val) iter数 ： 35 => cross entropy : 2.3001488829151397
# (train) iter数 ： 36 => cross entropy : 2.298082424741359
#   (val) iter数 ： 36 => cross entropy : 2.297167773826394
# (train) iter数 ： 37 => cross entropy : 2.279594820444849
#   (val) iter数 ： 37 => cross entropy : 2.29159845571602
# (train) iter数 ： 38 => cross entropy : 2.26414911802886
#   (val) iter数 ： 38 => cross entropy : 2.272938362991248
# (train) iter数 ： 39 => cross entropy : 2.277864645313359
#   (val) iter数 ： 39 => cross entropy : 2.273736980643195
# (train) iter数 ： 40 => cross entropy : 2.272813676337845
#   (val) iter数 ： 40 => cross entropy : 2.331774079049048
# (train) iter数 ： 41 => cross entropy : 2.29442045569554
#   (val) iter数 ： 41 => cross entropy : 2.31712430239804
# (train) iter数 ： 42 => cross entropy : 2.292354645229539
#   (val) iter数 ： 42 => cross entropy : 2.295968053876346
# (train) iter数 ： 43 => cross entropy : 2.276280510139109
#   (val) iter数 ： 43 => cross entropy : 2.303075222762615
# (train) iter数 ： 44 => cross entropy : 2.2774411786144992
#   (val) iter数 ： 44 => cross entropy : 2.318797655280461
# (train) iter数 ： 45 => cross entropy : 2.2703889951699785
#   (val) iter数 ： 45 => cross entropy : 2.2966450448288525
# (train) iter数 ： 46 => cross entropy : 2.2574707094871345
#   (val) iter数 ： 46 => cross entropy : 2.293252276776028
# (train) iter数 ： 47 => cross entropy : 2.26728576523644
#   (val) iter数 ： 47 => cross entropy : 2.3269940717570603
# (train) iter数 ： 48 => cross entropy : 2.254184476561814
#   (val) iter数 ： 48 => cross entropy : 2.3056352745705775
# (train) iter数 ： 49 => cross entropy : 2.276573364880899
#   (val) iter数 ： 49 => cross entropy : 2.2849413269680614
# (train) iter数 ： 50 => cross entropy : 2.250394860418924
#   (val) iter数 ： 50 => cross entropy : 2.3027954965259396
# (train) iter数 ： 51 => cross entropy : 2.2681560303092048
#   (val) iter数 ： 51 => cross entropy : 2.292162906723386
# (train) iter数 ： 52 => cross entropy : 2.260085134711003
#   (val) iter数 ： 52 => cross entropy : 2.27459334745646
# (train) iter数 ： 53 => cross entropy : 2.2250084791743836
#   (val) iter数 ： 53 => cross entropy : 2.348362095540381
# (train) iter数 ： 54 => cross entropy : 2.3127536796006907
#   (val) iter数 ： 54 => cross entropy : 2.282680372825219
# (train) iter数 ： 55 => cross entropy : 2.2799661111395957
#   (val) iter数 ： 55 => cross entropy : 2.3074274492171165
# (train) iter数 ： 56 => cross entropy : 2.2948054536877467
#   (val) iter数 ： 56 => cross entropy : 2.3004492076189167
# (train) iter数 ： 57 => cross entropy : 2.276844338148719
#   (val) iter数 ： 57 => cross entropy : 2.301161813277229
# (train) iter数 ： 58 => cross entropy : 2.2440909584478845
#   (val) iter数 ： 58 => cross entropy : 2.3199324935626087
# (train) iter数 ： 59 => cross entropy : 2.258487374952868
#   (val) iter数 ： 59 => cross entropy : 2.3086132800323864
# (train) iter数 ： 60 => cross entropy : 2.274980230710592
#   (val) iter数 ： 60 => cross entropy : 2.2605895440381594
# (train) iter数 ： 61 => cross entropy : 2.272014817068573
#   (val) iter数 ： 61 => cross entropy : 2.3048855449113588
# (train) iter数 ： 62 => cross entropy : 2.25436980251557
#   (val) iter数 ： 62 => cross entropy : 2.30518157385649
# (train) iter数 ： 63 => cross entropy : 2.273490287499076
#   (val) iter数 ： 63 => cross entropy : 2.280743576416289
# (train) iter数 ： 64 => cross entropy : 2.241468999642779
#   (val) iter数 ： 64 => cross entropy : 2.324373621285497
# (train) iter数 ： 65 => cross entropy : 2.2739910166154265
#   (val) iter数 ： 65 => cross entropy : 2.306195122056223
# (train) iter数 ： 66 => cross entropy : 2.2435571038346604
#   (val) iter数 ： 66 => cross entropy : 2.291867764445147
# (train) iter数 ： 67 => cross entropy : 2.2430798099625235
#   (val) iter数 ： 67 => cross entropy : 2.250048024720557
# (train) iter数 ： 68 => cross entropy : 2.2672501471572892
#   (val) iter数 ： 68 => cross entropy : 2.302347547898976
# (train) iter数 ： 69 => cross entropy : 2.2727714307811193
#   (val) iter数 ： 69 => cross entropy : 2.2536481724242043
# (train) iter数 ： 70 => cross entropy : 2.259865600406054
#   (val) iter数 ： 70 => cross entropy : 2.257797049425025
# (train) iter数 ： 71 => cross entropy : 2.271773805701767
#   (val) iter数 ： 71 => cross entropy : 2.2779716270023984
# (train) iter数 ： 72 => cross entropy : 2.2209464095914138
#   (val) iter数 ： 72 => cross entropy : 2.3169219116165594
# (train) iter数 ： 73 => cross entropy : 2.255932443832412
#   (val) iter数 ： 73 => cross entropy : 2.242800424457807
# (train) iter数 ： 74 => cross entropy : 2.2715406648210847
#   (val) iter数 ： 74 => cross entropy : 2.2750835838006602
# (train) iter数 ： 75 => cross entropy : 2.2451319084497103
#   (val) iter数 ： 75 => cross entropy : 2.2947067534809875
# (train) iter数 ： 76 => cross entropy : 2.277700176093
#   (val) iter数 ： 76 => cross entropy : 2.2629285706405264
# (train) iter数 ： 77 => cross entropy : 2.2345139377263963
#   (val) iter数 ： 77 => cross entropy : 2.2701453636953235
# (train) iter数 ： 78 => cross entropy : 2.242802998140258
#   (val) iter数 ： 78 => cross entropy : 2.2867553929258864
# (train) iter数 ： 79 => cross entropy : 2.239307720893308
#   (val) iter数 ： 79 => cross entropy : 2.274422830744201
# (train) iter数 ： 80 => cross entropy : 2.261673587855389
#   (val) iter数 ： 80 => cross entropy : 2.2795019917021686
# (train) iter数 ： 81 => cross entropy : 2.256352301357411
#   (val) iter数 ： 81 => cross entropy : 2.2739248907206395
# (train) iter数 ： 82 => cross entropy : 2.260020694191865
#   (val) iter数 ： 82 => cross entropy : 2.264131118802969
# (train) iter数 ： 83 => cross entropy : 2.18975924044164
#   (val) iter数 ： 83 => cross entropy : 2.290702037721045
# (train) iter数 ： 84 => cross entropy : 2.2070049536333674
#   (val) iter数 ： 84 => cross entropy : 2.269951508435526
# (train) iter数 ： 85 => cross entropy : 2.258281351666319
#   (val) iter数 ： 85 => cross entropy : 2.3114188180862683
# (train) iter数 ： 86 => cross entropy : 2.260732962572239
#   (val) iter数 ： 86 => cross entropy : 2.2654864261412726
# (train) iter数 ： 87 => cross entropy : 2.221620820594709
#   (val) iter数 ： 87 => cross entropy : 2.2888517581652126
# (train) iter数 ： 88 => cross entropy : 2.252836692299362
#   (val) iter数 ： 88 => cross entropy : 2.264569038943301
# (train) iter数 ： 89 => cross entropy : 2.23774982419707
#   (val) iter数 ： 89 => cross entropy : 2.305899286748921
# (train) iter数 ： 90 => cross entropy : 2.264756568722546
#   (val) iter数 ： 90 => cross entropy : 2.248367183754643
# (train) iter数 ： 91 => cross entropy : 2.2451028346564144
#   (val) iter数 ： 91 => cross entropy : 2.19234087922376
# (train) iter数 ： 92 => cross entropy : 2.2093003812312135
#   (val) iter数 ： 92 => cross entropy : 2.2675159392889546
# (train) iter数 ： 93 => cross entropy : 2.141872460720012
#   (val) iter数 ： 93 => cross entropy : 2.2772266143368873
# (train) iter数 ： 94 => cross entropy : 2.23328868814948
#   (val) iter数 ： 94 => cross entropy : 2.2458028698942147
# (train) iter数 ： 95 => cross entropy : 2.2284892498418274
#   (val) iter数 ： 95 => cross entropy : 2.2430398250615746
# (train) iter数 ： 96 => cross entropy : 2.162195828065467
#   (val) iter数 ： 96 => cross entropy : 2.2366257623919794
# (train) iter数 ： 97 => cross entropy : 2.166217954694382
#   (val) iter数 ： 97 => cross entropy : 2.286463590223826
# (train) iter数 ： 98 => cross entropy : 2.182280193995627
#   (val) iter数 ： 98 => cross entropy : 2.292131558106805
# (train) iter数 ： 99 => cross entropy : 2.1726505985228535
#   (val) iter数 ： 99 => cross entropy : 2.285255736794873
# (train) iter数 ： 100 => cross entropy : 2.1360316166810183
#   (val) iter数 ： 100 => cross entropy : 2.306670553032167
# (train) iter数 ： 101 => cross entropy : 2.242649412445864
#   (val) iter数 ： 101 => cross entropy : 2.097623895207108
# (train) iter数 ： 102 => cross entropy : 2.1350444072240524
#   (val) iter数 ： 102 => cross entropy : 2.1819795219899847
# (train) iter数 ： 103 => cross entropy : 2.181086547127675
#   (val) iter数 ： 103 => cross entropy : 2.105861311044489
# (train) iter数 ： 104 => cross entropy : 2.1461017582520294
#   (val) iter数 ： 104 => cross entropy : 2.2507749743110583
# (train) iter数 ： 105 => cross entropy : 2.1789666369925635
#   (val) iter数 ： 105 => cross entropy : 2.2754838943481834
# (train) iter数 ： 106 => cross entropy : 2.214910260795686
#   (val) iter数 ： 106 => cross entropy : 2.145612877930895
# (train) iter数 ： 107 => cross entropy : 2.1838416828237066
#   (val) iter数 ： 107 => cross entropy : 2.2205476351159645
# (train) iter数 ： 108 => cross entropy : 2.0827353501009904
#   (val) iter数 ： 108 => cross entropy : 2.2779546710226892
# (train) iter数 ： 109 => cross entropy : 2.2144212652065187
#   (val) iter数 ： 109 => cross entropy : 2.193722447275849
# (train) iter数 ： 110 => cross entropy : 2.16451268158319
#   (val) iter数 ： 110 => cross entropy : 2.1826922019189055
# (train) iter数 ： 111 => cross entropy : 2.1623056192001266
#   (val) iter数 ： 111 => cross entropy : 2.25895174974525
# (train) iter数 ： 112 => cross entropy : 2.173205168833762
#   (val) iter数 ： 112 => cross entropy : 2.2464067795856333
# (train) iter数 ： 113 => cross entropy : 2.1602744931120945
#   (val) iter数 ： 113 => cross entropy : 2.2236235918699645
# (train) iter数 ： 114 => cross entropy : 2.1291067299933824
#   (val) iter数 ： 114 => cross entropy : 2.190481307651147
# (train) iter数 ： 115 => cross entropy : 2.1409287067966054
#   (val) iter数 ： 115 => cross entropy : 2.156987416954609
# (train) iter数 ： 116 => cross entropy : 2.1192393706120547
#   (val) iter数 ： 116 => cross entropy : 2.2229915940501135
# (train) iter数 ： 117 => cross entropy : 2.0857107699582236
#   (val) iter数 ： 117 => cross entropy : 2.1482875036822473
# (train) iter数 ： 118 => cross entropy : 2.106791545758371
#   (val) iter数 ： 118 => cross entropy : 2.148883267426708
# (train) iter数 ： 119 => cross entropy : 2.11491653641537
#   (val) iter数 ： 119 => cross entropy : 2.151572804582856
# (train) iter数 ： 120 => cross entropy : 2.1150560716681053
#   (val) iter数 ： 120 => cross entropy : 2.222587214566562
# (train) iter数 ： 121 => cross entropy : 2.127807728728648
#   (val) iter数 ： 121 => cross entropy : 2.1367832705986096
# (train) iter数 ： 122 => cross entropy : 2.0991325830984144
#   (val) iter数 ： 122 => cross entropy : 2.2051794359709698
# (train) iter数 ： 123 => cross entropy : 2.157499734632393
#   (val) iter数 ： 123 => cross entropy : 2.161769072008567
# (train) iter数 ： 124 => cross entropy : 2.103889519930638
#   (val) iter数 ： 124 => cross entropy : 2.1372660095257188
# (train) iter数 ： 125 => cross entropy : 2.139040783950302
#   (val) iter数 ： 125 => cross entropy : 2.2199229280652495
# (train) iter数 ： 126 => cross entropy : 2.1114136861235706
#   (val) iter数 ： 126 => cross entropy : 2.128443580356708
# (train) iter数 ： 127 => cross entropy : 2.0271806360012063
#   (val) iter数 ： 127 => cross entropy : 2.143922302154241
# (train) iter数 ： 128 => cross entropy : 2.0798592252779877
#   (val) iter数 ： 128 => cross entropy : 2.19909039048332
# (train) iter数 ： 129 => cross entropy : 2.151098644431091
#   (val) iter数 ： 129 => cross entropy : 2.0605109143614917
# (train) iter数 ： 130 => cross entropy : 2.0912778592599994
#   (val) iter数 ： 130 => cross entropy : 2.182796492911225
# (train) iter数 ： 131 => cross entropy : 2.1178982848863153
#   (val) iter数 ： 131 => cross entropy : 2.164386272849613
# (train) iter数 ： 132 => cross entropy : 2.15767234523596
#   (val) iter数 ： 132 => cross entropy : 2.1402674749156745
# (train) iter数 ： 133 => cross entropy : 2.1902498415190554
#   (val) iter数 ： 133 => cross entropy : 2.168528455061899
# (train) iter数 ： 134 => cross entropy : 2.1268634505467006
#   (val) iter数 ： 134 => cross entropy : 2.144186473671195
# (train) iter数 ： 135 => cross entropy : 2.0067870294545096
#   (val) iter数 ： 135 => cross entropy : 2.2414125369486078
# (train) iter数 ： 136 => cross entropy : 2.1139224723638006
#   (val) iter数 ： 136 => cross entropy : 2.139069723522407
# (train) iter数 ： 137 => cross entropy : 2.0222045214237
#   (val) iter数 ： 137 => cross entropy : 2.129493228829869
# (train) iter数 ： 138 => cross entropy : 1.9609623663096103
#   (val) iter数 ： 138 => cross entropy : 2.116517557832242
# (train) iter数 ： 139 => cross entropy : 2.0609803323130524
#   (val) iter数 ： 139 => cross entropy : 2.1327754706775717
# (train) iter数 ： 140 => cross entropy : 2.0805244804845566
#   (val) iter数 ： 140 => cross entropy : 2.058416395563214
# (train) iter数 ： 141 => cross entropy : 2.05634686688903
#   (val) iter数 ： 141 => cross entropy : 2.0639729607934996
# (train) iter数 ： 142 => cross entropy : 2.0201346518194114
#   (val) iter数 ： 142 => cross entropy : 2.1819160541998115
# (train) iter数 ： 143 => cross entropy : 1.980844689793071
#   (val) iter数 ： 143 => cross entropy : 2.1019528242814
# (train) iter数 ： 144 => cross entropy : 2.169335660504582
#   (val) iter数 ： 144 => cross entropy : 2.0843998132340738
# (train) iter数 ： 145 => cross entropy : 2.131640577591344
#   (val) iter数 ： 145 => cross entropy : 2.1725427933067296
# (train) iter数 ： 146 => cross entropy : 2.068836314197197
#   (val) iter数 ： 146 => cross entropy : 2.0158803144900825
# (train) iter数 ： 147 => cross entropy : 2.041789506991145
#   (val) iter数 ： 147 => cross entropy : 1.9312230005730193
# (train) iter数 ： 148 => cross entropy : 2.068059090255673
#   (val) iter数 ： 148 => cross entropy : 2.1249476154521885
# (train) iter数 ： 149 => cross entropy : 2.0331695977321007
#   (val) iter数 ： 149 => cross entropy : 2.002835624061993
# (train) iter数 ： 150 => cross entropy : 2.0643213400457596
#   (val) iter数 ： 150 => cross entropy : 2.1698527878896776
# (train) iter数 ： 151 => cross entropy : 1.931860414137207
#   (val) iter数 ： 151 => cross entropy : 2.099836016708557
# (train) iter数 ： 152 => cross entropy : 2.07734910054645
#   (val) iter数 ： 152 => cross entropy : 2.0952439989789684
# (train) iter数 ： 153 => cross entropy : 2.0484089211107985
#   (val) iter数 ： 153 => cross entropy : 2.0637238950772763
# (train) iter数 ： 154 => cross entropy : 2.0313961427990015
#   (val) iter数 ： 154 => cross entropy : 2.037017497393515
# (train) iter数 ： 155 => cross entropy : 2.05076689083265
#   (val) iter数 ： 155 => cross entropy : 1.9694710551793528
# (train) iter数 ： 156 => cross entropy : 2.1088703528842863
#   (val) iter数 ： 156 => cross entropy : 2.2378316224658463
# (train) iter数 ： 157 => cross entropy : 2.0321333566711197
#   (val) iter数 ： 157 => cross entropy : 2.0939857283470102
# (train) iter数 ： 158 => cross entropy : 2.072653593913792
#   (val) iter数 ： 158 => cross entropy : 2.0478449686151117
# (train) iter数 ： 159 => cross entropy : 1.9406411364581133
#   (val) iter数 ： 159 => cross entropy : 1.961036116490756
# (train) iter数 ： 160 => cross entropy : 2.0768926065956457
#   (val) iter数 ： 160 => cross entropy : 2.1016427539775195
# (train) iter数 ： 161 => cross entropy : 2.030325760582174
#   (val) iter数 ： 161 => cross entropy : 2.052379060696562
# (train) iter数 ： 162 => cross entropy : 2.0133626429640112
#   (val) iter数 ： 162 => cross entropy : 2.078769290375923
# (train) iter数 ： 163 => cross entropy : 1.9710600349229357
#   (val) iter数 ： 163 => cross entropy : 1.988525496172266
# (train) iter数 ： 164 => cross entropy : 1.9583939594172486
#   (val) iter数 ： 164 => cross entropy : 2.0879875310951452
# (train) iter数 ： 165 => cross entropy : 2.071229175210951
#   (val) iter数 ： 165 => cross entropy : 2.0799995525871715
# (train) iter数 ： 166 => cross entropy : 1.9743935663015688
#   (val) iter数 ： 166 => cross entropy : 2.130987761142346
# (train) iter数 ： 167 => cross entropy : 2.0119443309557425
#   (val) iter数 ： 167 => cross entropy : 2.0317114531867078
# (train) iter数 ： 168 => cross entropy : 1.985511699580539
#   (val) iter数 ： 168 => cross entropy : 1.980941875995228
# (train) iter数 ： 169 => cross entropy : 2.037323552722806
#   (val) iter数 ： 169 => cross entropy : 2.053108843252109
# (train) iter数 ： 170 => cross entropy : 1.9635479781643868
#   (val) iter数 ： 170 => cross entropy : 2.072768577707906
# (train) iter数 ： 171 => cross entropy : 1.9938850984602852
#   (val) iter数 ： 171 => cross entropy : 2.03865100560513
# (train) iter数 ： 172 => cross entropy : 1.8979105596720716
#   (val) iter数 ： 172 => cross entropy : 2.109100336599336
# (train) iter数 ： 173 => cross entropy : 2.082332697841673
#   (val) iter数 ： 173 => cross entropy : 2.012628795759278
# (train) iter数 ： 174 => cross entropy : 2.0363102558966597
#   (val) iter数 ： 174 => cross entropy : 2.0909588950869487
# (train) iter数 ： 175 => cross entropy : 1.9497199860718895
#   (val) iter数 ： 175 => cross entropy : 2.060554129525378
# (train) iter数 ： 176 => cross entropy : 1.969006848556797
#   (val) iter数 ： 176 => cross entropy : 2.0367176012112274
# (train) iter数 ： 177 => cross entropy : 2.0620015087650545
#   (val) iter数 ： 177 => cross entropy : 2.004712279323747
# (train) iter数 ： 178 => cross entropy : 1.9461526344126843
#   (val) iter数 ： 178 => cross entropy : 2.0100120427218306
# (train) iter数 ： 179 => cross entropy : 1.9567219444590465
#   (val) iter数 ： 179 => cross entropy : 1.993301779906698
# (train) iter数 ： 180 => cross entropy : 1.9250460947891055
#   (val) iter数 ： 180 => cross entropy : 2.0122976599849003
# (train) iter数 ： 181 => cross entropy : 1.9392720287152287
#   (val) iter数 ： 181 => cross entropy : 2.0403787356775838
# (train) iter数 ： 182 => cross entropy : 1.8004997916631127
#   (val) iter数 ： 182 => cross entropy : 2.036477020385948
# (train) iter数 ： 183 => cross entropy : 2.02441517903739
#   (val) iter数 ： 183 => cross entropy : 2.047756388390804
# (train) iter数 ： 184 => cross entropy : 2.0178867782839873
#   (val) iter数 ： 184 => cross entropy : 1.985511246073445
# (train) iter数 ： 185 => cross entropy : 2.009014876836998
#   (val) iter数 ： 185 => cross entropy : 1.9597722164421179
# (train) iter数 ： 186 => cross entropy : 1.8808514473242426
#   (val) iter数 ： 186 => cross entropy : 2.024906461779208
# (train) iter数 ： 187 => cross entropy : 1.9722550543126809
#   (val) iter数 ： 187 => cross entropy : 2.045389557707046
# (train) iter数 ： 188 => cross entropy : 2.010186546404912
#   (val) iter数 ： 188 => cross entropy : 1.8254550277663826
# (train) iter数 ： 189 => cross entropy : 1.9551913023118175
#   (val) iter数 ： 189 => cross entropy : 2.120142372827863
# (train) iter数 ： 190 => cross entropy : 1.9351623158736873
#   (val) iter数 ： 190 => cross entropy : 1.9683009873102948
# (train) iter数 ： 191 => cross entropy : 1.9408889294277145
#   (val) iter数 ： 191 => cross entropy : 1.9766156098405454
# (train) iter数 ： 192 => cross entropy : 2.0058648392908665
#   (val) iter数 ： 192 => cross entropy : 1.9558552240685534
# (train) iter数 ： 193 => cross entropy : 1.969144036837939
#   (val) iter数 ： 193 => cross entropy : 2.0671368351794626
# (train) iter数 ： 194 => cross entropy : 1.9127557004043163
#   (val) iter数 ： 194 => cross entropy : 2.0538289937365097
# (train) iter数 ： 195 => cross entropy : 1.9565295168641286
#   (val) iter数 ： 195 => cross entropy : 2.0090182022218985
# (train) iter数 ： 196 => cross entropy : 2.001148179987703
#   (val) iter数 ： 196 => cross entropy : 1.9823620959412454
# (train) iter数 ： 197 => cross entropy : 2.072436829711348
#   (val) iter数 ： 197 => cross entropy : 1.9802636515314669
# (train) iter数 ： 198 => cross entropy : 1.956660888712948
#   (val) iter数 ： 198 => cross entropy : 1.8920897980379914
# (train) iter数 ： 199 => cross entropy : 1.846433277914823
#   (val) iter数 ： 199 => cross entropy : 2.0731686362489143
# (train) iter数 ： 200 => cross entropy : 2.0394364029715972
#   (val) iter数 ： 200 => cross entropy : 2.0789302729276073
# (train) iter数 ： 201 => cross entropy : 1.9362954261259882
#   (val) iter数 ： 201 => cross entropy : 1.9255094548186074
# (train) iter数 ： 202 => cross entropy : 1.9561992667788086
#   (val) iter数 ： 202 => cross entropy : 2.060190461032904
# (train) iter数 ： 203 => cross entropy : 1.9424633070279764
#   (val) iter数 ： 203 => cross entropy : 2.04387131975785
# (train) iter数 ： 204 => cross entropy : 1.9366816803313256
#   (val) iter数 ： 204 => cross entropy : 1.987787274850662
# (train) iter数 ： 205 => cross entropy : 1.9766720372132267
#   (val) iter数 ： 205 => cross entropy : 1.9733739633426368
# (train) iter数 ： 206 => cross entropy : 1.9606960330751009
#   (val) iter数 ： 206 => cross entropy : 1.9850849022294683
# (train) iter数 ： 207 => cross entropy : 1.8643279206416339
#   (val) iter数 ： 207 => cross entropy : 1.8986482654073673
# (train) iter数 ： 208 => cross entropy : 1.957215790117365
#   (val) iter数 ： 208 => cross entropy : 2.0812402923210587
# (train) iter数 ： 209 => cross entropy : 1.8844156013886377
#   (val) iter数 ： 209 => cross entropy : 2.053608891443351
# (train) iter数 ： 210 => cross entropy : 1.9023160823385243
#   (val) iter数 ： 210 => cross entropy : 1.9837445240274327
# (train) iter数 ： 211 => cross entropy : 1.8732050123607888
#   (val) iter数 ： 211 => cross entropy : 2.062317510230985
# (train) iter数 ： 212 => cross entropy : 2.0240255832820586
#   (val) iter数 ： 212 => cross entropy : 2.1124507491298217
# (train) iter数 ： 213 => cross entropy : 1.8716942651824018
#   (val) iter数 ： 213 => cross entropy : 2.0553871708330895
# (train) iter数 ： 214 => cross entropy : 1.962486284365025
#   (val) iter数 ： 214 => cross entropy : 1.8901267633182912
# (train) iter数 ： 215 => cross entropy : 1.8707453640684524
#   (val) iter数 ： 215 => cross entropy : 2.082018683847558
# (train) iter数 ： 216 => cross entropy : 2.0362126695427025
#   (val) iter数 ： 216 => cross entropy : 1.9471491404805563
# (train) iter数 ： 217 => cross entropy : 1.8703829621816135
#   (val) iter数 ： 217 => cross entropy : 1.9790791974435642
# (train) iter数 ： 218 => cross entropy : 1.9690852870763587
#   (val) iter数 ： 218 => cross entropy : 1.9854454098662573
# (train) iter数 ： 219 => cross entropy : 1.9302656679592614
#   (val) iter数 ： 219 => cross entropy : 1.9706091457727184
# (train) iter数 ： 220 => cross entropy : 2.0118889159513347
#   (val) iter数 ： 220 => cross entropy : 1.912592379500869
# (train) iter数 ： 221 => cross entropy : 1.9638177173138136
#   (val) iter数 ： 221 => cross entropy : 2.0215973185746843
# (train) iter数 ： 222 => cross entropy : 1.8839258706892323
#   (val) iter数 ： 222 => cross entropy : 1.932174534759771
# (train) iter数 ： 223 => cross entropy : 1.7181821965437303
#   (val) iter数 ： 223 => cross entropy : 2.0224214752719094
# (train) iter数 ： 224 => cross entropy : 2.05448946066482
#   (val) iter数 ： 224 => cross entropy : 1.8404742148551922
# (train) iter数 ： 225 => cross entropy : 1.984507109693825
#   (val) iter数 ： 225 => cross entropy : 1.8048713916893744
# (train) iter数 ： 226 => cross entropy : 1.8772749355549934
#   (val) iter数 ： 226 => cross entropy : 2.0217443496962466
# (train) iter数 ： 227 => cross entropy : 1.9624771201564017
#   (val) iter数 ： 227 => cross entropy : 1.8323459948307166
# (train) iter数 ： 228 => cross entropy : 1.9342425698449688
#   (val) iter数 ： 228 => cross entropy : 1.960564711118202
# (train) iter数 ： 229 => cross entropy : 2.005357478097975
#   (val) iter数 ： 229 => cross entropy : 1.9497349637371082
# (train) iter数 ： 230 => cross entropy : 1.9773108288890626
#   (val) iter数 ： 230 => cross entropy : 2.0089510735058247
# (train) iter数 ： 231 => cross entropy : 1.9136800892133898
#   (val) iter数 ： 231 => cross entropy : 2.0370047156628934
# (train) iter数 ： 232 => cross entropy : 1.9100424780945762
#   (val) iter数 ： 232 => cross entropy : 2.0845405336260443
# (train) iter数 ： 233 => cross entropy : 1.9099761916109133
#   (val) iter数 ： 233 => cross entropy : 1.9570146825924555
# (train) iter数 ： 234 => cross entropy : 1.9282769296317377
#   (val) iter数 ： 234 => cross entropy : 1.929331371649068
# (train) iter数 ： 235 => cross entropy : 1.7727546692917706
#   (val) iter数 ： 235 => cross entropy : 2.120704331350809
# (train) iter数 ： 236 => cross entropy : 1.9590032051853947
#   (val) iter数 ： 236 => cross entropy : 1.9152507312605829
# (train) iter数 ： 237 => cross entropy : 1.9853057951526616
#   (val) iter数 ： 237 => cross entropy : 1.9428359250102334
# (train) iter数 ： 238 => cross entropy : 1.9714417873314005
#   (val) iter数 ： 238 => cross entropy : 1.9406852415261984
# (train) iter数 ： 239 => cross entropy : 1.8350911064504327
#   (val) iter数 ： 239 => cross entropy : 1.976897237198945
# (train) iter数 ： 240 => cross entropy : 1.9343101233528117
#   (val) iter数 ： 240 => cross entropy : 1.9748190204292109
# (train) iter数 ： 241 => cross entropy : 1.875063322989538
#   (val) iter数 ： 241 => cross entropy : 1.9609529000759356
# (train) iter数 ： 242 => cross entropy : 1.9364932941253645
#   (val) iter数 ： 242 => cross entropy : 2.0058338369696473
# (train) iter数 ： 243 => cross entropy : 1.9407336674184599
#   (val) iter数 ： 243 => cross entropy : 2.0557765489910347
# (train) iter数 ： 244 => cross entropy : 1.9921701905471736
#   (val) iter数 ： 244 => cross entropy : 1.9583393210888564
# (train) iter数 ： 245 => cross entropy : 1.8807665439353087
#   (val) iter数 ： 245 => cross entropy : 1.889482630275631
# (train) iter数 ： 246 => cross entropy : 1.9101896806218919
#   (val) iter数 ： 246 => cross entropy : 1.9973812541218388
# (train) iter数 ： 247 => cross entropy : 1.8936001685113142
#   (val) iter数 ： 247 => cross entropy : 1.8506424581557228
# (train) iter数 ： 248 => cross entropy : 1.8516381590787618
#   (val) iter数 ： 248 => cross entropy : 2.088004259859441
# (train) iter数 ： 249 => cross entropy : 1.7671993134195305
#   (val) iter数 ： 249 => cross entropy : 1.8864258272981447
# (train) iter数 ： 250 => cross entropy : 1.878855723066822
#   (val) iter数 ： 250 => cross entropy : 1.9451791972581778
# (train) iter数 ： 251 => cross entropy : 1.940715738347433
#   (val) iter数 ： 251 => cross entropy : 1.8820382553030006
# (train) iter数 ： 252 => cross entropy : 1.8454298609430517
#   (val) iter数 ： 252 => cross entropy : 1.941620958277917
# (train) iter数 ： 253 => cross entropy : 1.8375620888972044
#   (val) iter数 ： 253 => cross entropy : 1.8836529088236205
# (train) iter数 ： 254 => cross entropy : 1.8730682979886688
#   (val) iter数 ： 254 => cross entropy : 2.042494248047146
# (train) iter数 ： 255 => cross entropy : 1.926274212490795
#   (val) iter数 ： 255 => cross entropy : 1.9156000004974403
# (train) iter数 ： 256 => cross entropy : 1.79671612718236
#   (val) iter数 ： 256 => cross entropy : 1.8996985720619355
# (train) iter数 ： 257 => cross entropy : 2.051571918354482
#   (val) iter数 ： 257 => cross entropy : 2.0165337353236477
# (train) iter数 ： 258 => cross entropy : 1.8198537375410844
#   (val) iter数 ： 258 => cross entropy : 1.961095438440375
# (train) iter数 ： 259 => cross entropy : 1.9656747773612508
#   (val) iter数 ： 259 => cross entropy : 1.9924065903791908
# (train) iter数 ： 260 => cross entropy : 1.6805789702231615
#   (val) iter数 ： 260 => cross entropy : 2.031521833069973
# (train) iter数 ： 261 => cross entropy : 1.9110925024830632
#   (val) iter数 ： 261 => cross entropy : 1.9836444266248787
# (train) iter数 ： 262 => cross entropy : 1.826518407154194
#   (val) iter数 ： 262 => cross entropy : 1.9471306718783248
# (train) iter数 ： 263 => cross entropy : 1.9312282888194217
#   (val) iter数 ： 263 => cross entropy : 1.8496484644394486
# (train) iter数 ： 264 => cross entropy : 1.884667179082052
#   (val) iter数 ： 264 => cross entropy : 1.8870515129758136
# (train) iter数 ： 265 => cross entropy : 1.9381035459861282
#   (val) iter数 ： 265 => cross entropy : 2.0795457086539106
# (train) iter数 ： 266 => cross entropy : 2.022312631417268
#   (val) iter数 ： 266 => cross entropy : 1.954496588996796
# (train) iter数 ： 267 => cross entropy : 1.9401198050095971
#   (val) iter数 ： 267 => cross entropy : 1.9579913859495734
# (train) iter数 ： 268 => cross entropy : 1.7678827102519035
#   (val) iter数 ： 268 => cross entropy : 1.8970590361069768
# (train) iter数 ： 269 => cross entropy : 1.9110640938228478
#   (val) iter数 ： 269 => cross entropy : 1.9984290118908925
# (train) iter数 ： 270 => cross entropy : 1.8743993907295469
#   (val) iter数 ： 270 => cross entropy : 1.7564345217833488
# (train) iter数 ： 271 => cross entropy : 1.8899379395248173
#   (val) iter数 ： 271 => cross entropy : 1.8366003052214142
# (train) iter数 ： 272 => cross entropy : 1.904100642698061
#   (val) iter数 ： 272 => cross entropy : 2.003099607704264
# (train) iter数 ： 273 => cross entropy : 1.9240391217870485
#   (val) iter数 ： 273 => cross entropy : 1.9070904068982495
# (train) iter数 ： 274 => cross entropy : 1.844353456694056
#   (val) iter数 ： 274 => cross entropy : 1.8386490692349255
# (train) iter数 ： 275 => cross entropy : 1.7052953317547186
#   (val) iter数 ： 275 => cross entropy : 1.9791379668320837
# (train) iter数 ： 276 => cross entropy : 1.787075075336302
#   (val) iter数 ： 276 => cross entropy : 1.9379101629031539
# (train) iter数 ： 277 => cross entropy : 1.8353498335373244
#   (val) iter数 ： 277 => cross entropy : 1.8344269496069217
# (train) iter数 ： 278 => cross entropy : 1.740432516522354
#   (val) iter数 ： 278 => cross entropy : 1.9783889624644289
# (train) iter数 ： 279 => cross entropy : 2.1255054724262616
#   (val) iter数 ： 279 => cross entropy : 2.1030870916030207
# (train) iter数 ： 280 => cross entropy : 1.9067755807591205
#   (val) iter数 ： 280 => cross entropy : 1.8436906363347128
# (train) iter数 ： 281 => cross entropy : 1.9546542862958551
#   (val) iter数 ： 281 => cross entropy : 1.8416726037446722
# (train) iter数 ： 282 => cross entropy : 1.797763043235792
#   (val) iter数 ： 282 => cross entropy : 1.9448688958629796
# (train) iter数 ： 283 => cross entropy : 1.882506875529101
#   (val) iter数 ： 283 => cross entropy : 1.762238788528704
# (train) iter数 ： 284 => cross entropy : 1.7487826281767125
#   (val) iter数 ： 284 => cross entropy : 1.9588774877056019
# (train) iter数 ： 285 => cross entropy : 1.8518043564510522
#   (val) iter数 ： 285 => cross entropy : 1.8731223537349728
# (train) iter数 ： 286 => cross entropy : 1.8502506623436972
#   (val) iter数 ： 286 => cross entropy : 1.9626871644578863
# (train) iter数 ： 287 => cross entropy : 1.8799011179220075
#   (val) iter数 ： 287 => cross entropy : 1.8299101691768656
# (train) iter数 ： 288 => cross entropy : 1.9592839311714887
#   (val) iter数 ： 288 => cross entropy : 1.7990643069975627
# (train) iter数 ： 289 => cross entropy : 1.8154182031138817
#   (val) iter数 ： 289 => cross entropy : 1.9007759165975497
# (train) iter数 ： 290 => cross entropy : 1.9633731688376423
#   (val) iter数 ： 290 => cross entropy : 1.840590382567156
# (train) iter数 ： 291 => cross entropy : 1.800327948287805
#   (val) iter数 ： 291 => cross entropy : 1.90357538408095
# (train) iter数 ： 292 => cross entropy : 1.9086159012556771
#   (val) iter数 ： 292 => cross entropy : 1.9242271263134634
# (train) iter数 ： 293 => cross entropy : 1.8828267083611117
#   (val) iter数 ： 293 => cross entropy : 1.8735964699131604
# (train) iter数 ： 294 => cross entropy : 1.860573470819076
#   (val) iter数 ： 294 => cross entropy : 1.9030627218436789
# (train) iter数 ： 295 => cross entropy : 1.656907239411613
#   (val) iter数 ： 295 => cross entropy : 1.7802007520866452
# (train) iter数 ： 296 => cross entropy : 1.8258425349540226
#   (val) iter数 ： 296 => cross entropy : 1.9429594483219645
# (train) iter数 ： 297 => cross entropy : 1.7976566494510267
#   (val) iter数 ： 297 => cross entropy : 1.862088983082179
# (train) iter数 ： 298 => cross entropy : 1.8192631017049157
#   (val) iter数 ： 298 => cross entropy : 2.005739303678227
# (train) iter数 ： 299 => cross entropy : 1.8270966374214475
#   (val) iter数 ： 299 => cross entropy : 1.8983472406706499
# (train) iter数 ： 300 => cross entropy : 1.891568975888915
#   (val) iter数 ： 300 => cross entropy : 1.8803434722146095
# (train) iter数 ： 301 => cross entropy : 1.7405182886968278
#   (val) iter数 ： 301 => cross entropy : 1.988950876996915
# (train) iter数 ： 302 => cross entropy : 1.7538093540129283
#   (val) iter数 ： 302 => cross entropy : 1.8463526009393327
# (train) iter数 ： 303 => cross entropy : 1.8770549915086912
#   (val) iter数 ： 303 => cross entropy : 1.8234067186220955
# (train) iter数 ： 304 => cross entropy : 1.759545615579792
#   (val) iter数 ： 304 => cross entropy : 1.9944996073924703
# (train) iter数 ： 305 => cross entropy : 1.947790213123155
#   (val) iter数 ： 305 => cross entropy : 1.9458480827639208
# (train) iter数 ： 306 => cross entropy : 1.8117664475229618
#   (val) iter数 ： 306 => cross entropy : 1.929938107782717
# (train) iter数 ： 307 => cross entropy : 1.9279314003774275
#   (val) iter数 ： 307 => cross entropy : 1.934822926675664
# (train) iter数 ： 308 => cross entropy : 1.7254572628911236
#   (val) iter数 ： 308 => cross entropy : 1.9291318738881529
# (train) iter数 ： 309 => cross entropy : 1.9007649904496817
#   (val) iter数 ： 309 => cross entropy : 1.966876530280648
# (train) iter数 ： 310 => cross entropy : 1.8807268318704784
#   (val) iter数 ： 310 => cross entropy : 1.9592199318703643
# (train) iter数 ： 311 => cross entropy : 1.7595269829330182
#   (val) iter数 ： 311 => cross entropy : 1.825146728794501
# (train) iter数 ： 312 => cross entropy : 1.7833065195316813
#   (val) iter数 ： 312 => cross entropy : 1.8204829668921505
# (train) iter数 ： 313 => cross entropy : 1.7450434986278205
#   (val) iter数 ： 313 => cross entropy : 1.8419530622111115
# (train) iter数 ： 314 => cross entropy : 1.7188107942237167
#   (val) iter数 ： 314 => cross entropy : 1.861315096859108
# (train) iter数 ： 315 => cross entropy : 1.7567770512543661
#   (val) iter数 ： 315 => cross entropy : 1.9214696390241934
# (train) iter数 ： 316 => cross entropy : 1.681501310490996
#   (val) iter数 ： 316 => cross entropy : 1.8579313775943747
# (train) iter数 ： 317 => cross entropy : 1.8242944418508413
#   (val) iter数 ： 317 => cross entropy : 1.8185543002117683
# (train) iter数 ： 318 => cross entropy : 1.7156811542009032
#   (val) iter数 ： 318 => cross entropy : 1.8354852024880537
# (train) iter数 ： 319 => cross entropy : 1.6924313597993519
#   (val) iter数 ： 319 => cross entropy : 1.8402675912463904
# (train) iter数 ： 320 => cross entropy : 1.7232804688124663
#   (val) iter数 ： 320 => cross entropy : 1.7346914387671193
# (train) iter数 ： 321 => cross entropy : 1.6625332751615147
#   (val) iter数 ： 321 => cross entropy : 1.930762726507174
# (train) iter数 ： 322 => cross entropy : 1.7459466616583257
#   (val) iter数 ： 322 => cross entropy : 1.9197183787341292
# (train) iter数 ： 323 => cross entropy : 1.7802320541472565
#   (val) iter数 ： 323 => cross entropy : 1.747633673244275
# (train) iter数 ： 324 => cross entropy : 1.7865211304382531
#   (val) iter数 ： 324 => cross entropy : 1.7257987975815592
# (train) iter数 ： 325 => cross entropy : 1.697879995222283
#   (val) iter数 ： 325 => cross entropy : 1.8107946501061702
# (train) iter数 ： 326 => cross entropy : 1.7102326212997625
#   (val) iter数 ： 326 => cross entropy : 1.9154993768377786
# (train) iter数 ： 327 => cross entropy : 1.803416059218902
#   (val) iter数 ： 327 => cross entropy : 1.6735585345459798
# (train) iter数 ： 328 => cross entropy : 1.7334911862069902
#   (val) iter数 ： 328 => cross entropy : 1.5483382266862116
# (train) iter数 ： 329 => cross entropy : 1.649983111285037
#   (val) iter数 ： 329 => cross entropy : 1.7587114606646077
# (train) iter数 ： 330 => cross entropy : 1.7457557430539845
#   (val) iter数 ： 330 => cross entropy : 1.6291739996576724
# (train) iter数 ： 331 => cross entropy : 1.7180133657492533
#   (val) iter数 ： 331 => cross entropy : 1.7298317442819702
# (train) iter数 ： 332 => cross entropy : 1.7657012247673862
#   (val) iter数 ： 332 => cross entropy : 1.7736001186655224
# (train) iter数 ： 333 => cross entropy : 1.68834529839699
#   (val) iter数 ： 333 => cross entropy : 1.825753713418083
# (train) iter数 ： 334 => cross entropy : 1.808315967085649
#   (val) iter数 ： 334 => cross entropy : 1.763096338041402
# (train) iter数 ： 335 => cross entropy : 1.6334939059844027
#   (val) iter数 ： 335 => cross entropy : 1.7240429561031285
# (train) iter数 ： 336 => cross entropy : 1.6085447094850664
#   (val) iter数 ： 336 => cross entropy : 1.5604669972453717
# (train) iter数 ： 337 => cross entropy : 1.698417040676483
#   (val) iter数 ： 337 => cross entropy : 1.6626826584150678
# (train) iter数 ： 338 => cross entropy : 1.8160034544965649
#   (val) iter数 ： 338 => cross entropy : 2.014096380455137
# (train) iter数 ： 339 => cross entropy : 1.9888066516648086
#   (val) iter数 ： 339 => cross entropy : 2.149471828430039
# (train) iter数 ： 340 => cross entropy : 1.8791460657339933
#   (val) iter数 ： 340 => cross entropy : 1.9350477661870746
# (train) iter数 ： 341 => cross entropy : 1.895702635395798
#   (val) iter数 ： 341 => cross entropy : 1.8633455300571573
# (train) iter数 ： 342 => cross entropy : 1.6441752691243126
#   (val) iter数 ： 342 => cross entropy : 1.9332783241703542
# (train) iter数 ： 343 => cross entropy : 1.7344882652104978
#   (val) iter数 ： 343 => cross entropy : 1.75125575333454
# (train) iter数 ： 344 => cross entropy : 1.5729112098959364
#   (val) iter数 ： 344 => cross entropy : 1.7057613301215597
# (train) iter数 ： 345 => cross entropy : 1.5474184688945885
#   (val) iter数 ： 345 => cross entropy : 1.8023969879774762
# (train) iter数 ： 346 => cross entropy : 1.5894289558612038
#   (val) iter数 ： 346 => cross entropy : 1.8254692657028693
# (train) iter数 ： 347 => cross entropy : 1.708276715982278
#   (val) iter数 ： 347 => cross entropy : 1.712173559806345
# (train) iter数 ： 348 => cross entropy : 1.7061144948217475
#   (val) iter数 ： 348 => cross entropy : 1.722199914176725
# (train) iter数 ： 349 => cross entropy : 1.5646563849773774
#   (val) iter数 ： 349 => cross entropy : 1.7671318375528757
# (train) iter数 ： 350 => cross entropy : 1.7757304824361755
#   (val) iter数 ： 350 => cross entropy : 1.6297972074430493
# (train) iter数 ： 351 => cross entropy : 1.6404294629080731
#   (val) iter数 ： 351 => cross entropy : 1.6927128480259779
# (train) iter数 ： 352 => cross entropy : 1.6930526744297947
#   (val) iter数 ： 352 => cross entropy : 1.6333832148197116
# (train) iter数 ： 353 => cross entropy : 1.562908596719479
#   (val) iter数 ： 353 => cross entropy : 1.654252608753108
# (train) iter数 ： 354 => cross entropy : 1.670218474360552
#   (val) iter数 ： 354 => cross entropy : 1.7384004520949965
# (train) iter数 ： 355 => cross entropy : 1.6875711804569968
#   (val) iter数 ： 355 => cross entropy : 1.5721677203639566
# (train) iter数 ： 356 => cross entropy : 1.6970426365070328
#   (val) iter数 ： 356 => cross entropy : 1.7142311767654883
# (train) iter数 ： 357 => cross entropy : 1.7891439553462238
#   (val) iter数 ： 357 => cross entropy : 1.6394151139880055
# (train) iter数 ： 358 => cross entropy : 1.6281731994997426
#   (val) iter数 ： 358 => cross entropy : 1.535746022774326
# (train) iter数 ： 359 => cross entropy : 1.572268681060646
#   (val) iter数 ： 359 => cross entropy : 1.7507584114764612
# (train) iter数 ： 360 => cross entropy : 1.596830526478226
#   (val) iter数 ： 360 => cross entropy : 1.7536492495933644
# (train) iter数 ： 361 => cross entropy : 1.5270468115466502
#   (val) iter数 ： 361 => cross entropy : 1.769344418432655
# (train) iter数 ： 362 => cross entropy : 1.6358937431002503
#   (val) iter数 ： 362 => cross entropy : 1.5964814342628384
# (train) iter数 ： 363 => cross entropy : 1.6190632448587126
#   (val) iter数 ： 363 => cross entropy : 1.7512006664524273
# (train) iter数 ： 364 => cross entropy : 1.5474376516050388
#   (val) iter数 ： 364 => cross entropy : 1.7166675061827519
# (train) iter数 ： 365 => cross entropy : 1.513951863394858
#   (val) iter数 ： 365 => cross entropy : 1.6228405303277704
# (train) iter数 ： 366 => cross entropy : 1.5559860528228486
#   (val) iter数 ： 366 => cross entropy : 1.5653525883913484
# (train) iter数 ： 367 => cross entropy : 1.4351494721405478
#   (val) iter数 ： 367 => cross entropy : 1.5666964235822474
# (train) iter数 ： 368 => cross entropy : 1.5807597827181938
#   (val) iter数 ： 368 => cross entropy : 1.723120072552147
# (train) iter数 ： 369 => cross entropy : 1.4384942924956494
#   (val) iter数 ： 369 => cross entropy : 1.905575918662406
# (train) iter数 ： 370 => cross entropy : 1.6398226510305607
#   (val) iter数 ： 370 => cross entropy : 1.5971328042138226
# (train) iter数 ： 371 => cross entropy : 1.5280963445725244
#   (val) iter数 ： 371 => cross entropy : 1.6030578616028301
# (train) iter数 ： 372 => cross entropy : 1.5542667291142653
#   (val) iter数 ： 372 => cross entropy : 1.5696968486621672
# (train) iter数 ： 373 => cross entropy : 1.4566084618608839
#   (val) iter数 ： 373 => cross entropy : 1.6863669087563224
# (train) iter数 ： 374 => cross entropy : 1.603901064065201
#   (val) iter数 ： 374 => cross entropy : 1.4849063464700234
# (train) iter数 ： 375 => cross entropy : 1.517406561071149
#   (val) iter数 ： 375 => cross entropy : 1.5751048961762644
# (train) iter数 ： 376 => cross entropy : 1.5584079226188603
#   (val) iter数 ： 376 => cross entropy : 1.6514387580279095
# (train) iter数 ： 377 => cross entropy : 1.4903508547717972
#   (val) iter数 ： 377 => cross entropy : 1.6825941488190779
# (train) iter数 ： 378 => cross entropy : 1.5649696502779904
#   (val) iter数 ： 378 => cross entropy : 1.5838932957534213
# (train) iter数 ： 379 => cross entropy : 1.4951979431218796
#   (val) iter数 ： 379 => cross entropy : 1.4138834810517
# (train) iter数 ： 380 => cross entropy : 1.48434550980056
#   (val) iter数 ： 380 => cross entropy : 1.598284557893007
# (train) iter数 ： 381 => cross entropy : 1.3856139442661495
#   (val) iter数 ： 381 => cross entropy : 1.699775937128272
# (train) iter数 ： 382 => cross entropy : 1.3995567919100584
#   (val) iter数 ： 382 => cross entropy : 1.5583237227478126
# (train) iter数 ： 383 => cross entropy : 1.4838658401694547
#   (val) iter数 ： 383 => cross entropy : 1.4603891694904503
# (train) iter数 ： 384 => cross entropy : 1.442389875884218
#   (val) iter数 ： 384 => cross entropy : 1.5890215293118324
# (train) iter数 ： 385 => cross entropy : 1.511219221273928
#   (val) iter数 ： 385 => cross entropy : 1.5094409481886217
# (train) iter数 ： 386 => cross entropy : 1.4890474378671694
#   (val) iter数 ： 386 => cross entropy : 1.8135403337603835
# (train) iter数 ： 387 => cross entropy : 1.9979432920869493
#   (val) iter数 ： 387 => cross entropy : 2.0103595266854835
# (train) iter数 ： 388 => cross entropy : 1.6286492969051254
#   (val) iter数 ： 388 => cross entropy : 1.5078864928852327
# (train) iter数 ： 389 => cross entropy : 1.4555075959477295
#   (val) iter数 ： 389 => cross entropy : 1.6229874420897368
# (train) iter数 ： 390 => cross entropy : 1.41332398638701
#   (val) iter数 ： 390 => cross entropy : 1.586591941080113
# (train) iter数 ： 391 => cross entropy : 1.4154962306056629
#   (val) iter数 ： 391 => cross entropy : 1.6804276509080716
# (train) iter数 ： 392 => cross entropy : 1.7330703076994967
#   (val) iter数 ： 392 => cross entropy : 1.8211679288749125
# (train) iter数 ： 393 => cross entropy : 1.4811054196505062
#   (val) iter数 ： 393 => cross entropy : 1.6545449494441855
# (train) iter数 ： 394 => cross entropy : 1.4482788392013344
#   (val) iter数 ： 394 => cross entropy : 1.6750136295835742
# (train) iter数 ： 395 => cross entropy : 1.749697315062634
#   (val) iter数 ： 395 => cross entropy : 1.6001281668671723
# (train) iter数 ： 396 => cross entropy : 1.5408729037632594
#   (val) iter数 ： 396 => cross entropy : 1.753999947690202
# (train) iter数 ： 397 => cross entropy : 1.5147044349216614
#   (val) iter数 ： 397 => cross entropy : 1.539084490439902
# (train) iter数 ： 398 => cross entropy : 1.2882911746393781
#   (val) iter数 ： 398 => cross entropy : 1.4224537717117525
# (train) iter数 ： 399 => cross entropy : 1.4898539687865682
#   (val) iter数 ： 399 => cross entropy : 1.4822909277135936
# (train) iter数 ： 400 => cross entropy : 1.2314205903996083
#   (val) iter数 ： 400 => cross entropy : 1.3510166949254423
# (train) iter数 ： 401 => cross entropy : 1.3166399124568442
#   (val) iter数 ： 401 => cross entropy : 1.4997434547950215
# (train) iter数 ： 402 => cross entropy : 1.3638610204488268
#   (val) iter数 ： 402 => cross entropy : 1.306857364800077
# (train) iter数 ： 403 => cross entropy : 1.2724908397941355
#   (val) iter数 ： 403 => cross entropy : 1.3381461464992155
# (train) iter数 ： 404 => cross entropy : 1.3647930637813979
#   (val) iter数 ： 404 => cross entropy : 1.3736093521740744
# (train) iter数 ： 405 => cross entropy : 1.3537653790544786
#   (val) iter数 ： 405 => cross entropy : 1.39552341992863
# (train) iter数 ： 406 => cross entropy : 1.4116126825015138
#   (val) iter数 ： 406 => cross entropy : 1.5030269301685433
# (train) iter数 ： 407 => cross entropy : 1.302300923173256
#   (val) iter数 ： 407 => cross entropy : 1.3522103161683114
# (train) iter数 ： 408 => cross entropy : 1.2908755352224142
#   (val) iter数 ： 408 => cross entropy : 1.4928979625390935
# (train) iter数 ： 409 => cross entropy : 1.3062400108714514
#   (val) iter数 ： 409 => cross entropy : 1.5585045141224374
# (train) iter数 ： 410 => cross entropy : 1.9005352543985978
#   (val) iter数 ： 410 => cross entropy : 1.58159644218967
# (train) iter数 ： 411 => cross entropy : 1.5292873937963742
#   (val) iter数 ： 411 => cross entropy : 1.6103160485437984
# (train) iter数 ： 412 => cross entropy : 1.5377485119836258
#   (val) iter数 ： 412 => cross entropy : 1.7571322751562555
# (train) iter数 ： 413 => cross entropy : 1.466792379448938
#   (val) iter数 ： 413 => cross entropy : 1.5143802147653478
# (train) iter数 ： 414 => cross entropy : 1.2290025808601666
#   (val) iter数 ： 414 => cross entropy : 1.5420515417459417
# (train) iter数 ： 415 => cross entropy : 1.4412094685111372
#   (val) iter数 ： 415 => cross entropy : 1.566994266486737
# (train) iter数 ： 416 => cross entropy : 1.4218149608651427
#   (val) iter数 ： 416 => cross entropy : 1.428753128661712
# (train) iter数 ： 417 => cross entropy : 1.3015082073826385
#   (val) iter数 ： 417 => cross entropy : 1.3682876576271144
# (train) iter数 ： 418 => cross entropy : 1.2755239622560417
#   (val) iter数 ： 418 => cross entropy : 1.4170942790003604
# (train) iter数 ： 419 => cross entropy : 1.2804631596408154
# ...
# (train) iter数 ： 465 => cross entropy : 0.08376510528556146
#   (val) iter数 ： 465 => cross entropy : 0.3117046676924449
# (train) iter数 ： 466 => cross entropy : 0.16625166885325704
#   (val) iter数 ： 466 => cross entropy : 0.2010979877563914
# (train) iter数 ： 467 => cross entropy : 0.20488820289442466
#   (val) iter数 ： 467 => cross entropy : 0.22531745034703887
# (train) iter数 ： 468 => cross entropy : 0.10569499345274819
#   (val) iter数 ： 468 => cross entropy : 0.11037293223606709
# (train) iter数 ： 469 => cross entropy : 0.2751340573551156
#   (val) iter数 ： 469 => cross entropy : 0.08546411044824348
# (train) iter数 ： 470 => cross entropy : 0.1574475415564105
#   (val) iter数 ： 470 => cross entropy : 0.16525808959785196
# (train) iter数 ： 471 => cross entropy : 0.15822851491829146
#   (val) iter数 ： 471 => cross entropy : 0.3955618180700454
# (train) iter数 ： 472 => cross entropy : 0.11485637420321715
#   (val) iter数 ： 472 => cross entropy : 0.19950217440207196
# (train) iter数 ： 473 => cross entropy : 0.16625629792882243
#   (val) iter数 ： 473 => cross entropy : 0.30283894736441197
# (train) iter数 ： 474 => cross entropy : 0.21396117318429175
#   (val) iter数 ： 474 => cross entropy : 0.27027493944322417
# (train) iter数 ： 475 => cross entropy : 0.15801964781237132
#   (val) iter数 ： 475 => cross entropy : 0.23842353900650703
# (train) iter数 ： 476 => cross entropy : 0.09059617783573003
#   (val) iter数 ： 476 => cross entropy : 0.12886597179061143
# (train) iter数 ： 477 => cross entropy : 0.07562661953409432
#   (val) iter数 ： 477 => cross entropy : 0.25735362977517556
# (train) iter数 ： 478 => cross entropy : 0.13987595564792063
#   (val) iter数 ： 478 => cross entropy : 0.19773926767190403
# (train) iter数 ： 479 => cross entropy : 0.11909333837259367
#   (val) iter数 ： 479 => cross entropy : 0.33324288527900986
# (train) iter数 ： 480 => cross entropy : 0.057446170941474306
#   (val) iter数 ： 480 => cross entropy : 0.11898704318171563
# (train) iter数 ： 481 => cross entropy : 0.21420209885022878
#   (val) iter数 ： 481 => cross entropy : 0.29782049509089975
# (train) iter数 ： 482 => cross entropy : 0.21904164886905889
#   (val) iter数 ： 482 => cross entropy : 0.15237914771917205
# (train) iter数 ： 483 => cross entropy : 0.1402081620707006
#   (val) iter数 ： 483 => cross entropy : 0.2036410363785202
# (train) iter数 ： 484 => cross entropy : 0.27859169464515143
#   (val) iter数 ： 484 => cross entropy : 0.31041541495020314
# (train) iter数 ： 485 => cross entropy : 0.1851994982458914
#   (val) iter数 ： 485 => cross entropy : 0.10916553326530197
# (train) iter数 ： 486 => cross entropy : 0.27167569179222967
#   (val) iter数 ： 486 => cross entropy : 0.17121010540362552
# (train) iter数 ： 487 => cross entropy : 0.07553703041883236
#   (val) iter数 ： 487 => cross entropy : 0.23919594396356253
# (train) iter数 ： 488 => cross entropy : 0.07693467603080978
#   (val) iter数 ： 488 => cross entropy : 0.26401065280235636
# (train) iter数 ： 489 => cross entropy : 0.150443313128504
#   (val) iter数 ： 489 => cross entropy : 0.4334380498343964
# (train) iter数 ： 490 => cross entropy : 0.18701988292296728
#   (val) iter数 ： 490 => cross entropy : 0.2967005195078361
# (train) iter数 ： 491 => cross entropy : 0.15920028783998175
#   (val) iter数 ： 491 => cross entropy : 0.3442159052899822
# (train) iter数 ： 492 => cross entropy : 0.17133696799885645
#   (val) iter数 ： 492 => cross entropy : 0.20466916945232044
# (train) iter数 ： 493 => cross entropy : 0.14816508605941756
#   (val) iter数 ： 493 => cross entropy : 0.27912370142001963
# (train) iter数 ： 494 => cross entropy : 0.08768827909862681
#   (val) iter数 ： 494 => cross entropy : 0.20290234402464266
# (train) iter数 ： 495 => cross entropy : 0.1530693930904744
#   (val) iter数 ： 495 => cross entropy : 0.28662307248232527
# (train) iter数 ： 496 => cross entropy : 0.2683030933344858
#   (val) iter数 ： 496 => cross entropy : 0.3287822108819827
# (train) iter数 ： 497 => cross entropy : 0.237441731580614
#   (val) iter数 ： 497 => cross entropy : 0.21525947108808083
# (train) iter数 ： 498 => cross entropy : 0.30465333508810355
#   (val) iter数 ： 498 => cross entropy : 0.19571268217977836
# (train) iter数 ： 499 => cross entropy : 0.1429955752423134
#   (val) iter数 ： 499 => cross entropy : 0.36036004815320377
# (train) iter数 ： 500 => cross entropy : 0.18222301364427373
#   (val) iter数 ： 500 => cross entropy : 0.22012019247735148
# (train) iter数 ： 501 => cross entropy : 0.058551470276209217
#   (val) iter数 ： 501 => cross entropy : 0.274122760356239
# (train) iter数 ： 502 => cross entropy : 0.09873676303507424
#   (val) iter数 ： 502 => cross entropy : 0.2008902793302382
# (train) iter数 ： 503 => cross entropy : 0.1440576925874896
#   (val) iter数 ： 503 => cross entropy : 0.2991958951178706
# (train) iter数 ： 504 => cross entropy : 0.12067832015849028
#   (val) iter数 ： 504 => cross entropy : 0.23890259796884084
# (train) iter数 ： 505 => cross entropy : 0.0780983613003384
#   (val) iter数 ： 505 => cross entropy : 0.16806887810548787
# (train) iter数 ： 506 => cross entropy : 0.1555500227888608
#   (val) iter数 ： 506 => cross entropy : 0.28238265431674037
# (train) iter数 ： 507 => cross entropy : 0.11111701071279861
#   (val) iter数 ： 507 => cross entropy : 0.2900315270313033
# (train) iter数 ： 508 => cross entropy : 0.11515342324666591
#   (val) iter数 ： 508 => cross entropy : 0.35606108672929965
# (train) iter数 ： 509 => cross entropy : 0.10784847187317266
#   (val) iter数 ： 509 => cross entropy : 0.382853686266487
# (train) iter数 ： 510 => cross entropy : 0.19203619887369439
#   (val) iter数 ： 510 => cross entropy : 0.2756313367240181
# (train) iter数 ： 511 => cross entropy : 0.16599141408540147
#   (val) iter数 ： 511 => cross entropy : 0.10397048908829337
# (train) iter数 ： 512 => cross entropy : 0.26042224090693294
#   (val) iter数 ： 512 => cross entropy : 0.30414603538362833
# (train) iter数 ： 513 => cross entropy : 0.09121123013105259
#   (val) iter数 ： 513 => cross entropy : 0.32769004227646586
# (train) iter数 ： 514 => cross entropy : 0.14245755088375392
#   (val) iter数 ： 514 => cross entropy : 0.33778844007480135
# (train) iter数 ： 515 => cross entropy : 0.3040223343988464
#   (val) iter数 ： 515 => cross entropy : 0.32736037822194475
# (train) iter数 ： 516 => cross entropy : 0.09081525398478373
#   (val) iter数 ： 516 => cross entropy : 0.2833024364201871
# (train) iter数 ： 517 => cross entropy : 0.1779329803861133
#   (val) iter数 ： 517 => cross entropy : 0.23493336494808476
# (train) iter数 ： 518 => cross entropy : 0.13227825546967584
#   (val) iter数 ： 518 => cross entropy : 0.27126273028321407
# (train) iter数 ： 519 => cross entropy : 0.07653807473424863
#   (val) iter数 ： 519 => cross entropy : 0.2565143921201382
# (train) iter数 ： 520 => cross entropy : 0.09740914788690946
#   (val) iter数 ： 520 => cross entropy : 0.27972340747044233
# (train) iter数 ： 521 => cross entropy : 0.17310107692423535
#   (val) iter数 ： 521 => cross entropy : 0.21049331645450708
# (train) iter数 ： 522 => cross entropy : 0.14442852904198217
#   (val) iter数 ： 522 => cross entropy : 0.18567173544396004
# (train) iter数 ： 523 => cross entropy : 0.044283185765726214
#   (val) iter数 ： 523 => cross entropy : 0.13310199300631806
# (train) iter数 ： 524 => cross entropy : 0.30981303433464713
#   (val) iter数 ： 524 => cross entropy : 0.6225778251668426
# (train) iter数 ： 525 => cross entropy : 0.3815101074520304
#   (val) iter数 ： 525 => cross entropy : 0.5824057812146812
# (train) iter数 ： 526 => cross entropy : 0.2931841496188485
#   (val) iter数 ： 526 => cross entropy : 0.42965764905980175
# (train) iter数 ： 527 => cross entropy : 0.1356591558282965
#   (val) iter数 ： 527 => cross entropy : 0.23047737866515572
# (train) iter数 ： 528 => cross entropy : 0.061894974637187294
#   (val) iter数 ： 528 => cross entropy : 0.26573394676516415
# (train) iter数 ： 529 => cross entropy : 0.06778672909395808
#   (val) iter数 ： 529 => cross entropy : 0.217229599375085
# (train) iter数 ： 530 => cross entropy : 0.2007975351319242
#   (val) iter数 ： 530 => cross entropy : 0.33542056324422687
# (train) iter数 ： 531 => cross entropy : 0.24540300605135543
#   (val) iter数 ： 531 => cross entropy : 0.20303654425424567
# (train) iter数 ： 532 => cross entropy : 0.15925418321163015
#   (val) iter数 ： 532 => cross entropy : 0.36145042333514804
# (train) iter数 ： 533 => cross entropy : 0.25059143516700744
#   (val) iter数 ： 533 => cross entropy : 0.2530798130412258
# (train) iter数 ： 534 => cross entropy : 0.09787992152577417
#   (val) iter数 ： 534 => cross entropy : 0.26781174272478303
# (train) iter数 ： 535 => cross entropy : 0.09521707400664979
#   (val) iter数 ： 535 => cross entropy : 0.29666913559129304
# (train) iter数 ： 536 => cross entropy : 0.15100755656401021
#   (val) iter数 ： 536 => cross entropy : 0.2464956412728304
# (train) iter数 ： 537 => cross entropy : 0.1302106025515319
#   (val) iter数 ： 537 => cross entropy : 0.18638892804651866
# (train) iter数 ： 538 => cross entropy : 0.0872678072613548
#   (val) iter数 ： 538 => cross entropy : 0.30135704562274834
# (train) iter数 ： 539 => cross entropy : 0.10775698083519214
#   (val) iter数 ： 539 => cross entropy : 0.21948217556012894
# (train) iter数 ： 540 => cross entropy : 0.10852922392067355
#   (val) iter数 ： 540 => cross entropy : 0.1351866562008163
# (train) iter数 ： 541 => cross entropy : 0.08625797828964347
#   (val) iter数 ： 541 => cross entropy : 0.09963478019993346
# (train) iter数 ： 542 => cross entropy : 0.042907470254108085
#   (val) iter数 ： 542 => cross entropy : 0.21437499737375298
# (train) iter数 ： 543 => cross entropy : 0.23452744854433655
#   (val) iter数 ： 543 => cross entropy : 0.11239927633933151
# (train) iter数 ： 544 => cross entropy : 0.18334440638647448
#   (val) iter数 ： 544 => cross entropy : 0.39816381800306916
# (train) iter数 ： 545 => cross entropy : 0.08597269250621362
#   (val) iter数 ： 545 => cross entropy : 0.12354186887239803
# (train) iter数 ： 546 => cross entropy : 0.06614093793389707
#   (val) iter数 ： 546 => cross entropy : 0.24006874614075052
# (train) iter数 ： 547 => cross entropy : 0.09636830302979754
#   (val) iter数 ： 547 => cross entropy : 0.3286904827745891
# (train) iter数 ： 548 => cross entropy : 0.1005344683853616
#   (val) iter数 ： 548 => cross entropy : 0.17276212220651477
# (train) iter数 ： 549 => cross entropy : 0.18682009876860217
#   (val) iter数 ： 549 => cross entropy : 0.26819765643490295
# (train) iter数 ： 550 => cross entropy : 0.2433709583736203
#   (val) iter数 ： 550 => cross entropy : 0.24693581661465647
# (train) iter数 ： 551 => cross entropy : 0.1456060042291236
#   (val) iter数 ： 551 => cross entropy : 0.272934448111184
# (train) iter数 ： 552 => cross entropy : 0.12733392948026784
#   (val) iter数 ： 552 => cross entropy : 0.22752431089552294
# (train) iter数 ： 553 => cross entropy : 0.14251041525406363
#   (val) iter数 ： 553 => cross entropy : 0.20763550733300962
# (train) iter数 ： 554 => cross entropy : 0.06389985674690613
#   (val) iter数 ： 554 => cross entropy : 0.1703221194354811
# (train) iter数 ： 555 => cross entropy : 0.24517221710259518
#   (val) iter数 ： 555 => cross entropy : 0.13599841639037266
# (train) iter数 ： 556 => cross entropy : 0.2411737336327689
#   (val) iter数 ： 556 => cross entropy : 0.38136529321788504
# (train) iter数 ： 557 => cross entropy : 0.07791276021284464
#   (val) iter数 ： 557 => cross entropy : 0.22025166616998476
# (train) iter数 ： 558 => cross entropy : 0.2559621182554925
#   (val) iter数 ： 558 => cross entropy : 0.13992679933227167
# (train) iter数 ： 559 => cross entropy : 0.158158494305174
#   (val) iter数 ： 559 => cross entropy : 0.33283761889579533
# (train) iter数 ： 560 => cross entropy : 0.12347102131088522
#   (val) iter数 ： 560 => cross entropy : 0.09352446811241404
# (train) iter数 ： 561 => cross entropy : 0.24122576535036813
#   (val) iter数 ： 561 => cross entropy : 0.25173255032961567
# (train) iter数 ： 562 => cross entropy : 0.286073801053188
#   (val) iter数 ： 562 => cross entropy : 0.25463934330134447
# (train) iter数 ： 563 => cross entropy : 0.12112473155729037
#   (val) iter数 ： 563 => cross entropy : 0.2547447429758381
# (train) iter数 ： 564 => cross entropy : 0.097040779062745
#   (val) iter数 ： 564 => cross entropy : 0.1279701804071828
# (train) iter数 ： 565 => cross entropy : 0.06566950262901657
#   (val) iter数 ： 565 => cross entropy : 0.21620852592447515
# (train) iter数 ： 566 => cross entropy : 0.221779212700929
#   (val) iter数 ： 566 => cross entropy : 0.23634961364323148
# (train) iter数 ： 567 => cross entropy : 0.11897700741521725
#   (val) iter数 ： 567 => cross entropy : 0.16728107097474876
# (train) iter数 ： 568 => cross entropy : 0.1106657644307296
#   (val) iter数 ： 568 => cross entropy : 0.2743591040433772
# (train) iter数 ： 569 => cross entropy : 0.14197387187054308
#   (val) iter数 ： 569 => cross entropy : 0.234206777456652
# (train) iter数 ： 570 => cross entropy : 0.14307585633058098
#   (val) iter数 ： 570 => cross entropy : 0.1239537613097273
# (train) iter数 ： 571 => cross entropy : 0.16428142770100296
#   (val) iter数 ： 571 => cross entropy : 0.2826068412379425
# (train) iter数 ： 572 => cross entropy : 0.19819156605886257
#   (val) iter数 ： 572 => cross entropy : 0.4298283969851352
# (train) iter数 ： 573 => cross entropy : 0.218538040450475
#   (val) iter数 ： 573 => cross entropy : 0.307824332731852
# (train) iter数 ： 574 => cross entropy : 0.23528065280162377
#   (val) iter数 ： 574 => cross entropy : 0.1859365624247786
# (train) iter数 ： 575 => cross entropy : 0.10458741715938942
#   (val) iter数 ： 575 => cross entropy : 0.17160534236316669
# (train) iter数 ： 576 => cross entropy : 0.30108371734707107
#   (val) iter数 ： 576 => cross entropy : 0.2867629096209483
# (train) iter数 ： 577 => cross entropy : 0.12813265996985587
#   (val) iter数 ： 577 => cross entropy : 0.23865680594271002
# (train) iter数 ： 578 => cross entropy : 0.1056932646841402
#   (val) iter数 ： 578 => cross entropy : 0.23031485731215529
# (train) iter数 ： 579 => cross entropy : 0.14980729520339117
#   (val) iter数 ： 579 => cross entropy : 0.19201220668711177
# (train) iter数 ： 580 => cross entropy : 0.14852856811698106
#   (val) iter数 ： 580 => cross entropy : 0.29560255299612176
# (train) iter数 ： 581 => cross entropy : 0.12034803608007527
#   (val) iter数 ： 581 => cross entropy : 0.11529916522705419
# (train) iter数 ： 582 => cross entropy : 0.07605698098293705
#   (val) iter数 ： 582 => cross entropy : 0.13268780001088465
# (train) iter数 ： 583 => cross entropy : 0.1884412718957259
#   (val) iter数 ： 583 => cross entropy : 0.32112675306656896
# (train) iter数 ： 584 => cross entropy : 0.21078128524282325
#   (val) iter数 ： 584 => cross entropy : 0.12021654560902553
# (train) iter数 ： 585 => cross entropy : 0.1997133106995264
#   (val) iter数 ： 585 => cross entropy : 0.2524408358680527
# (train) iter数 ： 586 => cross entropy : 0.12868325336619024
#   (val) iter数 ： 586 => cross entropy : 0.16550066551201525
# (train) iter数 ： 587 => cross entropy : 0.07631680132952168
#   (val) iter数 ： 587 => cross entropy : 0.27180430628348917
# (train) iter数 ： 588 => cross entropy : 0.21973070829301672
#   (val) iter数 ： 588 => cross entropy : 0.20333110592419532
# (train) iter数 ： 589 => cross entropy : 0.12473348277573865
#   (val) iter数 ： 589 => cross entropy : 0.3375317924148954
# (train) iter数 ： 590 => cross entropy : 0.08488084318207068
#   (val) iter数 ： 590 => cross entropy : 0.12839404711818223
# (train) iter数 ： 591 => cross entropy : 0.16961953207885994
#   (val) iter数 ： 591 => cross entropy : 0.16457731853919222
# (train) iter数 ： 592 => cross entropy : 0.06478121776905915
#   (val) iter数 ： 592 => cross entropy : 0.3539219808592627
# (train) iter数 ： 593 => cross entropy : 0.26807231007446747
#   (val) iter数 ： 593 => cross entropy : 0.3531227536680328
# (train) iter数 ： 594 => cross entropy : 0.16797305828770281
#   (val) iter数 ： 594 => cross entropy : 0.29035743945454034
# (train) iter数 ： 595 => cross entropy : 0.12349444755568945
#   (val) iter数 ： 595 => cross entropy : 0.1777712194849581
# (train) iter数 ： 596 => cross entropy : 0.14059363544050454
#   (val) iter数 ： 596 => cross entropy : 0.28853663292861625
# (train) iter数 ： 597 => cross entropy : 0.14611800666314864
#   (val) iter数 ： 597 => cross entropy : 0.21745213497702062
# (train) iter数 ： 598 => cross entropy : 0.13849073776810994
#   (val) iter数 ： 598 => cross entropy : 0.18483346605329795
# (train) iter数 ： 599 => cross entropy : 0.11507214915273085
#   (val) iter数 ： 599 => cross entropy : 0.17440121656269314
# (train) iter数 ： 600 => cross entropy : 0.04332175319303926
#   (val) iter数 ： 600 => cross entropy : 0.16811208699155866

# %%
plt.plot(model1.L_log,label="train")
plt.plot(model1.L_val_log,label="val")
plt.xlabel("iter")
plt.ylabel("cross entropy")
plt.legend()

# %%
# 予測
y_pred = model1.predict(X_val)[0]

# %%
# onehot化していたのでラベルに直す
y_val = np.argmax(y_val, axis=1)

# %%
# 正解率
accuracy_score(y_val,y_pred)
# Out:
# 0.9309166666666666

# %% [markdown]
# 今回では、バッチサイズ80で600iterを1エポックとし２エポック学習した。結果、上記グラフの通り、train,valデータ共にcross entropyが低くなり、適切に学習させる事ができた。
# 600iter(1エポックに相当)である程度下り、あとは飽和しているため、600iter(1エポックに相当)はデータ48000データを学習させればある程度学習させ適切な予測ができると考えられる。
# 今回はラベル10個（0〜9）なので1ラベルあたり4800で約5000個あれば事足りると思われる。
# （このデータセットもこのディープラーニングの学習を見越して適切な枚数のデータを用意しているを推定）

# %%
"""
語分類結果を並べて表示する。画像の上の表示は「推定結果/正解」である。

Parameters:
----------
y_pred : 推定値のndarray (n_samples,)
y_val : 検証データの正解ラベル(n_samples,)
X_val : 検証データの特徴量（n_samples, n_features)
"""
import numpy as np
import matplotlib.pyplot as plt
num = 36 # いくつ表示するか
true_false = y_pred==y_val
false_list = np.where(true_false==False)[0].astype(np.int)
if false_list.shape[0] < num:
    num = false_list.shape[0]
fig = plt.figure(figsize=(6, 6))
fig.subplots_adjust(left=0, right=0.8,  bottom=0, top=0.8, hspace=1, wspace=0.5)
for i in range(num):
    ax = fig.add_subplot(6, 6, i + 1, xticks=[], yticks=[])
    ax.set_title("{} / {}".format(y_pred[false_list[i]],y_val[false_list[i]]))
    ax.imshow(X_val.reshape(-1,28,28)[false_list[i]], cmap='gray')

# %%
# 正解ラベル：３、予測（確率が最も高い）：２　の予測確率分布の事例
true_false = y_pred!=y_val
plt.bar([i for i in range(10)], pred[1][true_false][4])
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# 予測が間違っているデータ（文字）を確認すると、例えば　”０と９”の共にマルがあるもの　や　”２と７”のようになんとなく形が似ているものである。これらは予測確率を見ると、確かに正解ラベルにもある程度予測の確率はでているが、それ以上に他の間違いやすいラベルに最も高い確率を返している事がわかった。（上記に一事例表示）
# 機械学習エンジニアは、このような間違いやすい傾向を把握すると共にこの間違いやすい場合にも適切に予測できるアルゴリズムを考えることも必要になってくると考える。

# %% [markdown]
# **ニューラルネットワークの学習はフォワードプロパゲーションとバックプロパゲションの繰り返しになります。**

# %% [markdown]
# ### 【問題1】重みの初期値を決めるコードの作成
# ニューラルネットワークの各層の重みの初期値を決めるコードを作成してください。
#
#
# 重みの初期値は様々な方法が提案されていますが、今回はガウス分布による単純な初期化を行います。バイアスに関しても同様です。
#
#
# 以下のコードを参考にしてください。標準偏差の値sigmaはハイパーパラメータです。発展的な重みの初期化方法については次のSprintで扱います。

# %% [markdown]
# ```python
#
#     def __init__(self, verbose = True):
#         self.verbose = verbose
#         self.L_log = []
#         self.L_val_log = []
#         batch_size = 80
#         n_features = 784
#         n_nodes1 = 400
#         n_nodes2 = 200
#         n_output = 10
#
#         sigma = 0.01 # ガウス分布の標準偏差
#
#         self.W1 = sigma * np.random.randn(n_features, n_nodes1) # 第1層目の重み　（係数）
#         self.W2 = sigma * np.random.randn(n_nodes1, n_nodes2) # 第2層目の重み（係数）
#         self.W3 = sigma * np.random.randn(n_nodes2, n_output) # 第3層目の重み　（係数）
#         self.B1 = sigma * np.random.randn(n_nodes1) # 第1層目の重み　（バイアス）
#         self.B2 = sigma * np.random.randn(n_nodes2) # 第2層目の重み　（バイアス）
#         self.B3 = sigma * np.random.randn(n_output) # 第3層目の重み　（バイアス）
# ```

# %% [markdown]
# #### 【問題2】フォワードプロパゲーションの実装
# 三層のニューラルネットワークの フォワードプロパゲーション を作成してください。以下の説明ではノード数は1層目は400、2層目は200としますが、変更しても構いません。
#
#
# 各層の数式を以下に示します。今回はそれぞれの記号が表す配列が、実装上どのようなndarrayのshapeになるかを併記してあります。

# %% [markdown]
# #### 「1層目」
#
#
# A
# 1
# =
# X
# ⋅
# W
# 1
# +
# B
# 1
#
# X
#  : 特徴量ベクトル (batch_size, n_features)
#
#
# W
# 1
#  : 1層目の重み (n_features, n_nodes1)
#
#
# B
# 1
#  : 1層目のバイアス (n_nodes1,)
#
#
# A
# 1
#  : 出力 (batch_size, n_nodes1)

# %% [markdown]
# #### 「1層目の活性化関数」
#
#
# Z
# 1
# =
# f
# (
# A
# 1
# )
#
# f
# (
# )
#  : 活性化関数
#
#
# Z
# 1
#  出力 (batch_size, n_nodes1)

# %% [markdown]
# #### 「2層目」
#
#
# A
# 2
# =
# Z
# 1
# ⋅
# W
# 2
# +
# B
# 2
#
# W
# 2
#  : 2層目の重み (n_nodes1, n_nodes2)
#
#
# B
# 2
#  : 2層目のバイアス (n_nodes2,)
#
#
# A
# 2
#  : 出力 (batch_size, n_nodes2)

# %% [markdown]
# #### 「2層目の活性化関数」
#
#
# Z
# 2
# =
# f
# (
# A
# 2
# )
#
# f
# (
# )
#  : 活性化関数
#
#
# Z
# 2
#  出力 (batch_size, n_nodes2)

# %% [markdown]
# #### 「3層目（出力層）」
#
#
# A
# 3
# =
# Z
# 2
# ⋅
# W
# 3
# +
# B
# 3
#
# W
# 3
#  : 3層目の重み (n_nodes2, n_output)
#
#
# B
# 3
#  : 3層目のバイアス (n_output,)
#
#
# A
# 3
#  : 出力 (batch_size, n_output)

# %% [markdown]
# #### 「3層目の活性化関数」
#
#
# Z
# 3
# =
# s
# o
# f
# t
# m
# a
# x
# (
# A
# 3
# )
#
# s
# o
# f
# t
# m
# a
# x
# (
# )
#  : ソフトマックス関数
#
#
# Z
# 3
#  出力 (batch_size, n_output)
#
#
# Z
# 3
#  は各ラベル（0〜9）に対する確率の配列である。

# %% [markdown]
# ```python
# def forward(self):    # フォーワードで入力から出力（確率が最も高いラベル）を計算する。
#
#         # 1層目
#         self.A1 = self.X @ self.W1 + self.B1
#         self.Z1 = self.activation(self.A1,"sigmoid")
#
#         # 2層目
#         self.A2 = self.Z1 @ self.W2 + self.B2
#         self.Z2 = self.activation(self.A2,"sigmoid")
#
#         # 3層目
#         self.A3 = self.Z2 @ self.W3 + self.B3
#         self.Z3 = self.softmax(self.A3)
#
# ```

# %% [markdown]
# ### 活性化関数（フォワードプロバゲーション）
#
#
# 活性化関数を作成し、フォワードプロパゲーションの中で使用します。切り替えられるように実装することを推奨しますが、片方でも構いません。
#
#
# **「シグモイド関数」**
#
#
# f
# (
# Z
# )
# =
# s
# i
# g
# m
# o
# i
# d
# (
# A
# )
# =
# 1
# 1
# +
# e
# x
# p
# (
# −
# A
# )
#
# 指数関数
# e
# x
# p
# (
# −
# A
# )
#  の計算はnp.expを使用してください。
#
#  **「ハイパボリックタンジェント関数」**
#
#
# 次の数式で表されますが、np.tanhひとつで実現できます。
#
#
# f
# (
# Z
# )
# =
# t
# a
# n
# h
# (
# A
# )
# =
# e
# x
# p
# (
# A
# )
# −
# e
# x
# p
# (
# −
# A
# )
# e
# x
# p
# (
# A
# )
# +
# e
# x
# p
# (
# −
# A
# )
#
# ＊現在ではこれらの代わりにReLUと呼ばれる活性化関数が一般的です。次のSprintで扱います。

# %% [markdown]
# ```python
# def activation(self, A, model): # 使用する活性化関数を関数化しておく。
#         if model == "sigmoid" :
#             return 1/(1+np.exp(-A))
#
#         if model == "tanh" :
#             return np.tanh(A)
# ```

# %% [markdown]
# #### ソフトマックス関数
#
#
# ソフトマックス関数を作成し、フォワードプロパゲーションの中で使用します。これも活性化関数の一種ですが、多クラス分類の出力層で使われる特性上、区別して扱われることが多いです。
#
#
# 次の数式です。
#
#
# Z
# 3
# _
# k
# =
# e
# x
# p
# (
# A
# 3
# _
# k
# )
# ∑
# n
# c
# i
# =
# 1
# e
# x
# p
# (
# A
# 3
# _
# i
# )
#
# Z
# 3
# k
#  :
# k
#  番目のクラスの確率ベクトル (batch_size,)
#
#
# A
# 3
# k
#  :
# k
#  番目のクラスにあたる前の層からのベクトル (batch_size,)
#
#
# n
# c
#  : クラスの数、n_output。今回のMNISTでは10。
#
#
# 分母は全てのクラスに相当する値を指数関数に通した上で足し合わせたものです。その中で、分子に
# k
#  番目のクラスを持ってくることで、
# k
#  番目のクラスである確率が求まります。
#
#
# これを10クラス分計算し、合わせたものが
# Z
# 3
#  です。

# %% [markdown]
# ```python
# def softmax(self,A3):       # 使用するソフトマックス関数を関数化しておく
#         batch_size = len(A3)
#         output = 10
#         Z3 = np.zeros((batch_size,output))
#         for i in range(batch_size):
#             for k in range (output):
#                 Z3[i][k] = np.exp(A3)[i][k]/np.sum(np.exp(A3), axis=1)[i]
#         return Z3
# ```

# %% [markdown]
# ### 【問題3】交差エントロピー誤差の実装
# 目的関数（損失関数）を作成します。
#
#
# 多クラス分類の目的関数である交差エントロピー誤差 $L$ は次の数式です。
#
#
# L
# =
# −
# 1
# n
# b
# n
# b
# ∑
# j
#
# n
# c
# ∑
# k
#
# y
# j
# k
# l
# o
# g
# (
# z
# 3
# _
# j
# k
# )
#
# $y_{ij}$ : $j$ 番目のサンプルの $k$ 番目のクラスの正解ラベル（one-hot表現で0か1のスカラー）
#
#
# $z_{3_ij}$ : $j$ 番目のサンプルの $k$ 番目のクラスの確率（スカラー）
#
#
# $n_{b}$ : バッチサイズ、batch_size
#
#
# $n_{c}$ : クラスの数、n_output（今回のMNISTでは10）
#
#
# サンプル1つあたりの誤差が求まります。

# %% [markdown]
# ```python
# def entropy(self,Z3, y_one_hot_label):  # 各ラベルの予測確率と正解ラベル（onehot）を引数にクロスエントロピを計算。その際、バッチ単位で平均したものを出力
#         batch_size = len(Z3)
#         L = -1/batch_size*np.sum(y_one_hot_label*np.log(Z3))
#         return L
# ```

# %% [markdown]
# ### 【問題4】バックプロパゲーションの実装
# 三層のニューラルネットワークのバックプロパゲーションを作成してください。確率的勾配降下法を行う部分です。
#
#
# 数式を以下に示します。
#
#
# まず、i層目の重みとバイアスの更新式です。 $W_i$ と $B_i$ に対し、更新後の $W_i^{\prime}$ と $B_i^{\prime}$ は次の数式で求められます。
#
#
# $$𝑊′𝑖=𝑊𝑖−𝛼∂𝐿∂𝑊𝑖𝐵′𝑖=𝐵𝑖−𝛼∂𝐿∂𝐵𝑖$$
#
# $\alpha$ : 学習率（層ごとに変えることも可能だが、基本的には全て同じとする）
#
#
# $\frac{\partial L}{\partial W_i}$ : $W_i$ に関する損失 $L$ の勾配
#
#
# $\frac{\partial L}{\partial B_i}$ : $B_i$ に関する損失 $L$ の勾配
#
#
# ＊この勾配はミニバッチのサンプル数分の合計または平均を考えます。ここでは合計を計算します。
#
#
# この更新方法はSprint3線形回帰やsprint4ロジスティック回帰における最急降下法と同様です。より効果的な更新方法が知られており、それは次のSprintで扱います。
#
#
# 勾配 $\frac{\partial L}{\partial W_i}$ や $\frac{\partial L}{\partial B_i}$ を求めるために、バックプロパゲーションを行います。以下の数式です。ハイパボリックタンジェント関数を使用した例を載せました。シグモイド関数の場合の数式はその後ろにあります。
#
#
# 「3層目」
#
#
# $$∂𝐿∂𝐴3=𝑍3−𝑌∂𝐿∂𝐵3=∑𝑗𝑛𝑏∂𝐿∂𝐴3_𝑗∂𝐿∂𝑊3=𝑍𝑇2⋅∂𝐿∂𝐴3∂𝐿∂𝑍2=∂𝐿∂𝐴3⋅𝑊𝑇3$$
#
# $\frac{\partial L}{\partial A_3}$ : $A_3$ に関する損失 $L$ の勾配 (batch_size, n_output)
#
#
# $\frac{\partial L}{\partial A_{3_j}}$ : j番目のサンプルの$A_3$ に関する損失 $L$ の勾配 (n_nodes2,)
#
#
# $\frac{\partial L}{\partial B_3}$ : $B_3$ に関する損失 $L$ の勾配 (n_output,)
#
#
# $\frac{\partial L}{\partial W_3}$ : $W_3$ に関する損失 $L$ の勾配 (n_nodes2, n_output)
#
#
# $\frac{\partial L}{\partial Z_2}$ : $Z_2$ に関する損失 $L$ の勾配 (batch_size, n_nodes2)
#
#
# $Z_{3}$ : ソフトマックス関数の出力 (batch_size, n_nodes2)
#
#
# $Y$ : 正解ラベル (batch_size, n_output)
#
#
# $Z_{2}$ : 2層目の活性化関数の出力 (batch_size, n_nodes2)
#
#
# $W_3$ : 3層目の重み (n_nodes2, n_output)
#
#
# 「2層目」
#
#
# $$∂𝐿∂𝐴2=∂𝐿∂𝑍2⊙{1−𝑡𝑎𝑛ℎ2(𝐴2)}∂𝐿∂𝐵2=∑𝑗𝑛𝑏∂𝐿∂𝐴2_𝑗∂𝐿∂𝑊2=𝑍𝑇1⋅∂𝐿∂𝐴2∂𝐿∂𝑍1=∂𝐿∂𝐴2⋅𝑊𝑇2$$
#
# $\frac{\partial L}{\partial A_2}$ : $A_2$ に関する損失 $L$ の勾配 (batch_size, n_nodes2)
#
#
# $\frac{\partial L}{\partial A_{2_j}}$ : j番目のサンプルの$A_2$ に関する損失 $L$ の勾配 (n_nodes2,)
#
#
# $\frac{\partial L}{\partial B_2}$ : $B_2$ に関する損失 $L$ の勾配 (n_output,)
#
#
# $\frac{\partial L}{\partial W_2}$ : $W_2$ に関する損失 $L$ の勾配 (n_nodes1, n_nodes2)
#
#
# $\frac{\partial L}{\partial Z_2}$ : $Z_2$ に関する損失 $L$ の勾配 (batch_size, n_nodes2)
#
#
# $A_2$ : 2層目の出力 (batch_size, n_nodes2)
#
#
# $Z_{1}$ : 1層目の活性化関数の出力 (batch_size, n_nodes1)
#
#
# $W_2$ : 2層目の重み (n_nodes1, n_nodes2)
#
#
# 「1層目」
#
#
# $$∂𝐿∂𝐴1=∂𝐿∂𝑍1⊙{1−𝑡𝑎𝑛ℎ2(𝐴1)}∂𝐿∂𝐵1=∑𝑗𝑛𝑏∂𝐿∂𝐴1_𝑗∂𝐿∂𝑊1=𝑋𝑇⋅∂𝐿∂𝐴1$$
#
# $\frac{\partial L}{\partial A_1}$ : $A_1$ に関する損失 $L$ の勾配 (batch_size, n_nodes1)
#
#
# $\frac{\partial L}{\partial A_{1_j}}$ : j番目のサンプルの$A_1$ に関する損失 $L$ の勾配 (n_nodes1,)
#
#
# $\frac{\partial L}{\partial B_1}$ : $B_1$ に関する損失 $L$ の勾配 (n_output,)
#
#
# $\frac{\partial L}{\partial W_1}$ : $W_1$ に関する損失 $L$ の勾配 (n_features, n_nodes1)
#
#
# $\frac{\partial L}{\partial Z_1}$ : $Z_1$ に関する損失 $L$ の勾配 (batch_size, n_nodes1)
#
#
# $A_1$ : 1層目の出力 (batch_size, n_nodes1)
#
#
# $X$ : 特徴量ベクトル (batch_size, n_features)
#
#
# $W_1$ : 1層目の重み (n_features, n_nodes1)
#
#
# 《補足》
#
#
# 活性化関数にシグモイド関数を使用した場合は、次のようになります。
#
#
# $$∂𝐿∂𝐴2=∂𝐿∂𝑍2⊙{1−𝑠𝑖𝑔𝑚𝑜𝑖𝑑(𝐴2)}𝑠𝑖𝑔𝑚𝑜𝑖𝑑(𝐴2)∂𝐿∂𝐴1=∂𝐿∂𝑍1⊙{1−𝑠𝑖𝑔𝑚𝑜𝑖𝑑(𝐴1)}𝑠𝑖𝑔𝑚𝑜𝑖𝑑(𝐴1)$$

# %% [markdown]
# ```python
# def backpro(self):  # フォーワードで求まった出力（予測値）を元に誤差を出し、そこから、逆伝搬で各層の重みの偏微分を算出し勾配降下で重みを更新
#
#         # 3層目
#         grad_A3 = self.Z3 - self.y
#         grad_B3 = np.sum(grad_A3, axis=0)
#         grad_W3 = self.Z2.T @ grad_A3
#         grad_Z2 = grad_A3 @ self.W3.T
#
#         # 2層目
#         grad_A2 = grad_Z2 * (1-np.tanh(self.A2)**2)
#         grad_B2 = np.sum(grad_A2, axis=0)
#         grad_W2 = self.Z1.T @ grad_A2
#         grad_Z1 = grad_A2 @ self.W2.T
#
#         # 1層目
#         grad_A1 = grad_Z1 * (1-np.tanh(self.A1)**2)
#         grad_B1 = np.sum(grad_A1, axis=0)
#         grad_W1 = self.X.T @ grad_A1
#
#         # 上記計算結果を元に各層の重み（係数W,バイアスB）を更新
#         self.W1 -= self.rate * grad_W1
#         self.B1 -= self.rate * grad_B1
#         self.W2 -= self.rate * grad_W2
#         self.B2 -= self.rate * grad_B2
#         self.W3 -= self.rate * grad_W3
#         self.B3 -= self.rate * grad_B3
# ```

# %% [markdown]
# ### 【問題5】推定
# 推定を行うメソッドを作成してください。
#
#
# フォワードプロパゲーションによって出力された10個の確率の中で、最も高いものはどれかを判定します。

# %% [markdown]
# ```python
# def predict(self, X):   # これまで学習したW1〜3, B1〜3,を使いフォーワードで入力から出力（確率が最も高いラベル）を計算
#         # 1層目
#         A1 = X @ self.W1 + self.B1
#         Z1 = self.activation(A1,"sigmoid")
#
#         # 2層目
#         A2 = Z1 @ self.W2 + self.B2
#         Z2 = self.activation(A2,"sigmoid")
#
#         # 3層目
#         A3 = Z2 @ self.W3 + self.B3
#         Z3 = self.softmax(A3)
#
#         return np.argmax(Z3, axis=1) , Z3
# ```

# %% [markdown]
# ### 【問題6】学習と推定
# MNISTのデータを学習・推定し、Accuracyを計算してください。

# %%
model_1 = ScratchSimpleNeuralNetrowkClassifier()
model_1.fit(X_train, y_train, X_val, y_val)
# Out:
# (train) iter数 ： 1 => cross entropy : 2.4657553221387993
#   (val) iter数 ： 1 => cross entropy : 2.53432109276093
# (train) iter数 ： 2 => cross entropy : 2.9865467692779952
#   (val) iter数 ： 2 => cross entropy : 3.754922324485582
# (train) iter数 ： 3 => cross entropy : 2.395141914047656
#   (val) iter数 ： 3 => cross entropy : 2.580568118608151
# (train) iter数 ： 4 => cross entropy : 2.361823001303211
#   (val) iter数 ： 4 => cross entropy : 2.3792417364852625
# (train) iter数 ： 5 => cross entropy : 2.3380403172598903
#   (val) iter数 ： 5 => cross entropy : 2.3106662363712758
# (train) iter数 ： 6 => cross entropy : 2.312327249824752
#   (val) iter数 ： 6 => cross entropy : 2.3366915921980342
# (train) iter数 ： 7 => cross entropy : 2.322960090698339
#   (val) iter数 ： 7 => cross entropy : 2.3101479573530654
# (train) iter数 ： 8 => cross entropy : 2.2968119217144696
#   (val) iter数 ： 8 => cross entropy : 2.3049054085683296
# (train) iter数 ： 9 => cross entropy : 2.2037990154879097
#   (val) iter数 ： 9 => cross entropy : 2.321586207888064
# (train) iter数 ： 10 => cross entropy : 2.2852464665617807
#   (val) iter数 ： 10 => cross entropy : 2.3057014742179143
# (train) iter数 ： 11 => cross entropy : 2.2847110807781057
#   (val) iter数 ： 11 => cross entropy : 2.2651681961749652
# (train) iter数 ： 12 => cross entropy : 2.2572382227535934
#   (val) iter数 ： 12 => cross entropy : 2.334691927152328
# (train) iter数 ： 13 => cross entropy : 2.301619082178694
#   (val) iter数 ： 13 => cross entropy : 2.303050807610668
# (train) iter数 ： 14 => cross entropy : 2.29918101689578
#   (val) iter数 ： 14 => cross entropy : 2.3222293605281963
# (train) iter数 ： 15 => cross entropy : 2.277529914970484
#   (val) iter数 ： 15 => cross entropy : 2.279439999469018
# (train) iter数 ： 16 => cross entropy : 2.288483159851166
#   (val) iter数 ： 16 => cross entropy : 2.2962568880650123
# (train) iter数 ： 17 => cross entropy : 2.2759408525074307
#   (val) iter数 ： 17 => cross entropy : 2.299339611887786
# (train) iter数 ： 18 => cross entropy : 2.2716154703201563
#   (val) iter数 ： 18 => cross entropy : 2.299465290502917
# (train) iter数 ： 19 => cross entropy : 2.2750462747707156
#   (val) iter数 ： 19 => cross entropy : 2.297907424557724
# (train) iter数 ： 20 => cross entropy : 2.2699215170695597
#   (val) iter数 ： 20 => cross entropy : 2.2809917926300947
# (train) iter数 ： 21 => cross entropy : 2.2875673486519577
#   (val) iter数 ： 21 => cross entropy : 2.3092021254393207
# (train) iter数 ： 22 => cross entropy : 2.2626395135224984
#   (val) iter数 ： 22 => cross entropy : 2.2684881733840108
# (train) iter数 ： 23 => cross entropy : 2.302354232801125
#   (val) iter数 ： 23 => cross entropy : 2.302969574755901
# (train) iter数 ： 24 => cross entropy : 2.2536408877715033
#   (val) iter数 ： 24 => cross entropy : 2.30565929654812
# (train) iter数 ： 25 => cross entropy : 2.2835619815453683
#   (val) iter数 ： 25 => cross entropy : 2.2700144689296287
# (train) iter数 ： 26 => cross entropy : 2.2986117266322355
#   (val) iter数 ： 26 => cross entropy : 2.303739246151011
# (train) iter数 ： 27 => cross entropy : 2.268150251681067
#   (val) iter数 ： 27 => cross entropy : 2.2765798030159785
# (train) iter数 ： 28 => cross entropy : 2.2516432570372635
#   (val) iter数 ： 28 => cross entropy : 2.3291811244611837
# (train) iter数 ： 29 => cross entropy : 2.2741498068012205
#   (val) iter数 ： 29 => cross entropy : 2.2880683629439176
# (train) iter数 ： 30 => cross entropy : 2.2411867065798794
#   (val) iter数 ： 30 => cross entropy : 2.3048649091844817
# (train) iter数 ： 31 => cross entropy : 2.2737871707720836
#   (val) iter数 ： 31 => cross entropy : 2.2964225520620305
# (train) iter数 ： 32 => cross entropy : 2.302906371496675
#   (val) iter数 ： 32 => cross entropy : 2.2678103951277926
# (train) iter数 ： 33 => cross entropy : 2.2725349742740977
#   (val) iter数 ： 33 => cross entropy : 2.304599948657737
# (train) iter数 ： 34 => cross entropy : 2.2677109208068766
#   (val) iter数 ： 34 => cross entropy : 2.2921123923487747
# (train) iter数 ： 35 => cross entropy : 2.278844582252379
#   (val) iter数 ： 35 => cross entropy : 2.2878721827875528
# (train) iter数 ： 36 => cross entropy : 2.300197946512423
#   (val) iter数 ： 36 => cross entropy : 2.268183783088344
# (train) iter数 ： 37 => cross entropy : 2.2797152790346735
#   (val) iter数 ： 37 => cross entropy : 2.3011893237518466
# (train) iter数 ： 38 => cross entropy : 2.26789898074391
#   (val) iter数 ： 38 => cross entropy : 2.2510047958696546
# (train) iter数 ： 39 => cross entropy : 2.2805591327120807
#   (val) iter数 ： 39 => cross entropy : 2.2926129572578136
# (train) iter数 ： 40 => cross entropy : 2.272494401127426
#   (val) iter数 ： 40 => cross entropy : 2.2879857467257785
# (train) iter数 ： 41 => cross entropy : 2.2921032697649397
#   (val) iter数 ： 41 => cross entropy : 2.2999271588821473
# (train) iter数 ： 42 => cross entropy : 2.2905147428544903
#   (val) iter数 ： 42 => cross entropy : 2.316177960535749
# (train) iter数 ： 43 => cross entropy : 2.2738871748550884
#   (val) iter数 ： 43 => cross entropy : 2.276798845138751
# (train) iter数 ： 44 => cross entropy : 2.276989878831037
#   (val) iter数 ： 44 => cross entropy : 2.2997352112829716
# (train) iter数 ： 45 => cross entropy : 2.273527647888516
#   (val) iter数 ： 45 => cross entropy : 2.2985121215155275
# (train) iter数 ： 46 => cross entropy : 2.2592200258008623
#   (val) iter数 ： 46 => cross entropy : 2.3265803211474063
# (train) iter数 ： 47 => cross entropy : 2.2693978455854724
#   (val) iter数 ： 47 => cross entropy : 2.283227820302057
# (train) iter数 ： 48 => cross entropy : 2.2519920472820654
#   (val) iter数 ： 48 => cross entropy : 2.263340316610765
# (train) iter数 ： 49 => cross entropy : 2.2798094816380075
#   (val) iter数 ： 49 => cross entropy : 2.289694335620358
# (train) iter数 ： 50 => cross entropy : 2.2573709456562265
#   (val) iter数 ： 50 => cross entropy : 2.279852181644784
# (train) iter数 ： 51 => cross entropy : 2.2741908663544343
#   (val) iter数 ： 51 => cross entropy : 2.306487420220634
# (train) iter数 ： 52 => cross entropy : 2.264633439104484
#   (val) iter数 ： 52 => cross entropy : 2.3020296563604647
# (train) iter数 ： 53 => cross entropy : 2.231888827426309
#   (val) iter数 ： 53 => cross entropy : 2.2709144007719084
# (train) iter数 ： 54 => cross entropy : 2.3109896761393594
#   (val) iter数 ： 54 => cross entropy : 2.3123906926408027
# (train) iter数 ： 55 => cross entropy : 2.2796707037763393
#   (val) iter数 ： 55 => cross entropy : 2.268875189505623
# (train) iter数 ： 56 => cross entropy : 2.2928721843292688
#   (val) iter数 ： 56 => cross entropy : 2.2814165282294994
# (train) iter数 ： 57 => cross entropy : 2.2736099111393133
#   (val) iter数 ： 57 => cross entropy : 2.270636933373257
# (train) iter数 ： 58 => cross entropy : 2.243931121264277
#   (val) iter数 ： 58 => cross entropy : 2.297583496913604
# (train) iter数 ： 59 => cross entropy : 2.2617450831370434
#   (val) iter数 ： 59 => cross entropy : 2.2383550332118545
# (train) iter数 ： 60 => cross entropy : 2.276843471286908
#   (val) iter数 ： 60 => cross entropy : 2.294200998023943
# (train) iter数 ： 61 => cross entropy : 2.2749591104809492
#   (val) iter数 ： 61 => cross entropy : 2.277007993446708
# (train) iter数 ： 62 => cross entropy : 2.2530781930043466
#   (val) iter数 ： 62 => cross entropy : 2.2884765540392284
# (train) iter数 ： 63 => cross entropy : 2.271805756854657
#   (val) iter数 ： 63 => cross entropy : 2.2920233789759545
# (train) iter数 ： 64 => cross entropy : 2.2475962675751937
#   (val) iter数 ： 64 => cross entropy : 2.274820605011347
# (train) iter数 ： 65 => cross entropy : 2.2760582466878647
#   (val) iter数 ： 65 => cross entropy : 2.2619613857137004
# (train) iter数 ： 66 => cross entropy : 2.2475020756215516
#   (val) iter数 ： 66 => cross entropy : 2.3126071064225617
# (train) iter数 ： 67 => cross entropy : 2.2517868412670565
#   (val) iter数 ： 67 => cross entropy : 2.2784040540469594
# (train) iter数 ： 68 => cross entropy : 2.2721790908867256
#   (val) iter数 ： 68 => cross entropy : 2.283185666171325
# (train) iter数 ： 69 => cross entropy : 2.273097716821102
#   (val) iter数 ： 69 => cross entropy : 2.2667294976004437
# (train) iter数 ： 70 => cross entropy : 2.2664597791947845
#   (val) iter数 ： 70 => cross entropy : 2.2735860594656203
# (train) iter数 ： 71 => cross entropy : 2.2714405423002275
#   (val) iter数 ： 71 => cross entropy : 2.268543335184504
# (train) iter数 ： 72 => cross entropy : 2.2334082664263066
#   (val) iter数 ： 72 => cross entropy : 2.305674547830877
# (train) iter数 ： 73 => cross entropy : 2.255082328987877
#   (val) iter数 ： 73 => cross entropy : 2.2636591362368166
# (train) iter数 ： 74 => cross entropy : 2.2771518058713762
#   (val) iter数 ： 74 => cross entropy : 2.2732948944197107
# (train) iter数 ： 75 => cross entropy : 2.2517702216825395
#   (val) iter数 ： 75 => cross entropy : 2.2964775453651214
# (train) iter数 ： 76 => cross entropy : 2.280950239316362
#   (val) iter数 ： 76 => cross entropy : 2.273802829083069
# (train) iter数 ： 77 => cross entropy : 2.2361967500770628
#   (val) iter数 ： 77 => cross entropy : 2.280958819579965
# (train) iter数 ： 78 => cross entropy : 2.2604585708864335
#   (val) iter数 ： 78 => cross entropy : 2.2978302133057724
# (train) iter数 ： 79 => cross entropy : 2.246306858323778
#   (val) iter数 ： 79 => cross entropy : 2.2764727918879046
# (train) iter数 ： 80 => cross entropy : 2.2602433109762283
#   (val) iter数 ： 80 => cross entropy : 2.311398510141632
# (train) iter数 ： 81 => cross entropy : 2.2625906743694517
#   (val) iter数 ： 81 => cross entropy : 2.313446018226241
# (train) iter数 ： 82 => cross entropy : 2.264719103732723
#   (val) iter数 ： 82 => cross entropy : 2.2955324605641487
# (train) iter数 ： 83 => cross entropy : 2.2228779798564
#   (val) iter数 ： 83 => cross entropy : 2.300610692599862
# (train) iter数 ： 84 => cross entropy : 2.2198583246363497
#   (val) iter数 ： 84 => cross entropy : 2.3114147049691653
# (train) iter数 ： 85 => cross entropy : 2.266872284288531
#   (val) iter数 ： 85 => cross entropy : 2.2504632072003177
# (train) iter数 ： 86 => cross entropy : 2.2727835105401573
#   (val) iter数 ： 86 => cross entropy : 2.267271053226503
# (train) iter数 ： 87 => cross entropy : 2.233845248678157
#   (val) iter数 ： 87 => cross entropy : 2.265649239369691
# (train) iter数 ： 88 => cross entropy : 2.2504910938748175
#   (val) iter数 ： 88 => cross entropy : 2.2796704748087335
# (train) iter数 ： 89 => cross entropy : 2.253733827946307
#   (val) iter数 ： 89 => cross entropy : 2.2846533298161815
# (train) iter数 ： 90 => cross entropy : 2.274933922249851
#   (val) iter数 ： 90 => cross entropy : 2.2682257234814585
# (train) iter数 ： 91 => cross entropy : 2.260108855540277
#   (val) iter数 ： 91 => cross entropy : 2.2539491569642984
# (train) iter数 ： 92 => cross entropy : 2.2268231651986454
#   (val) iter数 ： 92 => cross entropy : 2.2637726494209
# (train) iter数 ： 93 => cross entropy : 2.1801137868466722
#   (val) iter数 ： 93 => cross entropy : 2.260958978111568
# (train) iter数 ： 94 => cross entropy : 2.247538791200893
#   (val) iter数 ： 94 => cross entropy : 2.2755706027229357
# (train) iter数 ： 95 => cross entropy : 2.2470062232292247
#   (val) iter数 ： 95 => cross entropy : 2.2580783303429826
# (train) iter数 ： 96 => cross entropy : 2.192617232802616
#   (val) iter数 ： 96 => cross entropy : 2.290686374604957
# (train) iter数 ： 97 => cross entropy : 2.1928668202182395
#   (val) iter数 ： 97 => cross entropy : 2.2768690317307843
# (train) iter数 ： 98 => cross entropy : 2.2186099885756305
#   (val) iter数 ： 98 => cross entropy : 2.2520345613462815
# (train) iter数 ： 99 => cross entropy : 2.2044007483119468
#   (val) iter数 ： 99 => cross entropy : 2.1931074110890103
# (train) iter数 ： 100 => cross entropy : 2.1774273265932345
#   (val) iter数 ： 100 => cross entropy : 2.2807221546526257
# (train) iter数 ： 101 => cross entropy : 2.2632285553583453
#   (val) iter数 ： 101 => cross entropy : 2.258135546827233
# (train) iter数 ： 102 => cross entropy : 2.177076077649653
#   (val) iter数 ： 102 => cross entropy : 2.225372249081292
# (train) iter数 ： 103 => cross entropy : 2.208254266580965
#   (val) iter数 ： 103 => cross entropy : 2.3049049102453387
# (train) iter数 ： 104 => cross entropy : 2.173940178199969
#   (val) iter数 ： 104 => cross entropy : 2.20519109008773
# (train) iter数 ： 105 => cross entropy : 2.2231324696352512
#   (val) iter数 ： 105 => cross entropy : 2.2604346474140686
# (train) iter数 ： 106 => cross entropy : 2.238467772154688
#   (val) iter数 ： 106 => cross entropy : 2.2731181762643593
# (train) iter数 ： 107 => cross entropy : 2.212671923905802
#   (val) iter数 ： 107 => cross entropy : 2.1963505963067904
# (train) iter数 ： 108 => cross entropy : 2.1449729719169595
#   (val) iter数 ： 108 => cross entropy : 2.273742447473887
# (train) iter数 ： 109 => cross entropy : 2.243454681801746
#   (val) iter数 ： 109 => cross entropy : 2.249852996069951
# (train) iter数 ： 110 => cross entropy : 2.202561185992504
#   (val) iter数 ： 110 => cross entropy : 2.222846536082127
# (train) iter数 ： 111 => cross entropy : 2.1958835193274147
#   (val) iter数 ： 111 => cross entropy : 2.215524894191144
# (train) iter数 ： 112 => cross entropy : 2.202940069243391
#   (val) iter数 ： 112 => cross entropy : 2.208346941537137
# (train) iter数 ： 113 => cross entropy : 2.205537756643206
#   (val) iter数 ： 113 => cross entropy : 2.219346553942326
# (train) iter数 ： 114 => cross entropy : 2.173648377741642
#   (val) iter数 ： 114 => cross entropy : 2.2841445128315057
# (train) iter数 ： 115 => cross entropy : 2.183544623049178
#   (val) iter数 ： 115 => cross entropy : 2.13787471883523
# (train) iter数 ： 116 => cross entropy : 2.1551635330625403
#   (val) iter数 ： 116 => cross entropy : 2.205463219191104
# (train) iter数 ： 117 => cross entropy : 2.130991060792227
#   (val) iter数 ： 117 => cross entropy : 2.2286547669771326
# (train) iter数 ： 118 => cross entropy : 2.1557554726002537
#   (val) iter数 ： 118 => cross entropy : 2.250768454486818
# (train) iter数 ： 119 => cross entropy : 2.1516453339870285
#   (val) iter数 ： 119 => cross entropy : 2.2449822604302034
# (train) iter数 ： 120 => cross entropy : 2.1535289392261565
#   (val) iter数 ： 120 => cross entropy : 2.2067690013353976
# (train) iter数 ： 121 => cross entropy : 2.1618958897771607
#   (val) iter数 ： 121 => cross entropy : 2.192284969620181
# (train) iter数 ： 122 => cross entropy : 2.1360000608558645
#   (val) iter数 ： 122 => cross entropy : 2.212636247955707
# (train) iter数 ： 123 => cross entropy : 2.180117161807278
#   (val) iter数 ： 123 => cross entropy : 2.1335221267497757
# (train) iter数 ： 124 => cross entropy : 2.141261421259548
#   (val) iter数 ： 124 => cross entropy : 2.1975878800974153
# (train) iter数 ： 125 => cross entropy : 2.1775657352785367
#   (val) iter数 ： 125 => cross entropy : 2.257057608527945
# (train) iter数 ： 126 => cross entropy : 2.153551243112793
#   (val) iter数 ： 126 => cross entropy : 2.2322997830193403
# (train) iter数 ： 127 => cross entropy : 2.083939290336552
#   (val) iter数 ： 127 => cross entropy : 2.181825991427813
# (train) iter数 ： 128 => cross entropy : 2.11735362665361
#   (val) iter数 ： 128 => cross entropy : 2.264423538787444
# (train) iter数 ： 129 => cross entropy : 2.1757319966121815
#   (val) iter数 ： 129 => cross entropy : 2.1749801353532505
# (train) iter数 ： 130 => cross entropy : 2.1257823594471073
#   (val) iter数 ： 130 => cross entropy : 2.276064283448093
# (train) iter数 ： 131 => cross entropy : 2.1561160166437787
#   (val) iter数 ： 131 => cross entropy : 2.2177729120717764
# (train) iter数 ： 132 => cross entropy : 2.1839083229687506
#   (val) iter数 ： 132 => cross entropy : 2.1532103839931014
# (train) iter数 ： 133 => cross entropy : 2.207911220116188
#   (val) iter数 ： 133 => cross entropy : 2.244371383810009
# (train) iter数 ： 134 => cross entropy : 2.1639343045066033
#   (val) iter数 ： 134 => cross entropy : 2.153435151851571
# (train) iter数 ： 135 => cross entropy : 2.0540081255024543
#   (val) iter数 ： 135 => cross entropy : 2.1508049442237356
# (train) iter数 ： 136 => cross entropy : 2.1423791535093497
#   (val) iter数 ： 136 => cross entropy : 2.2085334288565828
# (train) iter数 ： 137 => cross entropy : 2.073216074772407
#   (val) iter数 ： 137 => cross entropy : 2.279925496763099
# (train) iter数 ： 138 => cross entropy : 1.9983687227773161
#   (val) iter数 ： 138 => cross entropy : 2.193154039171001
# (train) iter数 ： 139 => cross entropy : 2.089738358663425
#   (val) iter数 ： 139 => cross entropy : 2.096496969175129
# (train) iter数 ： 140 => cross entropy : 2.1119856768840997
#   (val) iter数 ： 140 => cross entropy : 2.2010232321412433
# (train) iter数 ： 141 => cross entropy : 2.086381335057499
#   (val) iter数 ： 141 => cross entropy : 2.1356250640977312
# (train) iter数 ： 142 => cross entropy : 2.0678491816064155
#   (val) iter数 ： 142 => cross entropy : 2.127705173484816
# (train) iter数 ： 143 => cross entropy : 2.014237796047727
#   (val) iter数 ： 143 => cross entropy : 2.1990858989527924
# (train) iter数 ： 144 => cross entropy : 2.178050448385055
#   (val) iter数 ： 144 => cross entropy : 2.122889207468606
# (train) iter数 ： 145 => cross entropy : 2.15248592948164
#   (val) iter数 ： 145 => cross entropy : 2.0199995101124566
# (train) iter数 ： 146 => cross entropy : 2.092600839728977
#   (val) iter数 ： 146 => cross entropy : 2.143005198453085
# (train) iter数 ： 147 => cross entropy : 2.0636780109628448
#   (val) iter数 ： 147 => cross entropy : 2.185070778013116
# (train) iter数 ： 148 => cross entropy : 2.1075279422262194
#   (val) iter数 ： 148 => cross entropy : 2.1565413085504526
# (train) iter数 ： 149 => cross entropy : 2.073732092890827
#   (val) iter数 ： 149 => cross entropy : 2.1075566625743356
# (train) iter数 ： 150 => cross entropy : 2.1033173946444568
#   (val) iter数 ： 150 => cross entropy : 2.041174925682499
# (train) iter数 ： 151 => cross entropy : 1.9799173720974783
#   (val) iter数 ： 151 => cross entropy : 2.2628572494728867
# (train) iter数 ： 152 => cross entropy : 2.102469824363219
#   (val) iter数 ： 152 => cross entropy : 2.127797613965624
# (train) iter数 ： 153 => cross entropy : 2.092961136019724
#   (val) iter数 ： 153 => cross entropy : 2.0004193568197914
# (train) iter数 ： 154 => cross entropy : 2.0739435070989876
#   (val) iter数 ： 154 => cross entropy : 2.139872057241754
# (train) iter数 ： 155 => cross entropy : 2.0809700821347272
#   (val) iter数 ： 155 => cross entropy : 2.139680089746605
# (train) iter数 ： 156 => cross entropy : 2.136844075455482
#   (val) iter数 ： 156 => cross entropy : 2.1433552735669403
# (train) iter数 ： 157 => cross entropy : 2.052950143560884
#   (val) iter数 ： 157 => cross entropy : 2.127007372013176
# (train) iter数 ： 158 => cross entropy : 2.1105797560674886
#   (val) iter数 ： 158 => cross entropy : 2.0338548527257885
# (train) iter数 ： 159 => cross entropy : 1.970810867273819
#   (val) iter数 ： 159 => cross entropy : 2.0668485869280566
# (train) iter数 ： 160 => cross entropy : 2.1045682020897716
#   (val) iter数 ： 160 => cross entropy : 2.116186798434659
# (train) iter数 ： 161 => cross entropy : 2.072644040436567
#   (val) iter数 ： 161 => cross entropy : 2.125789482404801
# (train) iter数 ： 162 => cross entropy : 2.048881008963102
#   (val) iter数 ： 162 => cross entropy : 2.1920963856202325
# (train) iter数 ： 163 => cross entropy : 2.008475087738168
#   (val) iter数 ： 163 => cross entropy : 1.962135204834297
# (train) iter数 ： 164 => cross entropy : 1.9987157494166397
#   (val) iter数 ： 164 => cross entropy : 2.1597549885529364
# (train) iter数 ： 165 => cross entropy : 2.107643090790512
#   (val) iter数 ： 165 => cross entropy : 2.006619503638698
# (train) iter数 ： 166 => cross entropy : 2.0003405584218017
#   (val) iter数 ： 166 => cross entropy : 2.0268130566858766
# (train) iter数 ： 167 => cross entropy : 2.0289058773815833
#   (val) iter数 ： 167 => cross entropy : 2.05984083055955
# (train) iter数 ： 168 => cross entropy : 2.0301577066607157
#   (val) iter数 ： 168 => cross entropy : 2.068045386703442
# (train) iter数 ： 169 => cross entropy : 2.0647115945082457
#   (val) iter数 ： 169 => cross entropy : 2.1492746654289916
# (train) iter数 ： 170 => cross entropy : 1.9892883823619387
#   (val) iter数 ： 170 => cross entropy : 2.1305385145389346
# (train) iter数 ： 171 => cross entropy : 2.0248849800237365
#   (val) iter数 ： 171 => cross entropy : 2.109135067557724
# (train) iter数 ： 172 => cross entropy : 1.935750742888171
#   (val) iter数 ： 172 => cross entropy : 2.1583256471488164
# (train) iter数 ： 173 => cross entropy : 2.1014655576857293
#   (val) iter数 ： 173 => cross entropy : 1.9485253511832483
# (train) iter数 ： 174 => cross entropy : 2.0642887087427577
#   (val) iter数 ： 174 => cross entropy : 2.018491397047652
# (train) iter数 ： 175 => cross entropy : 1.9902108675573928
#   (val) iter数 ： 175 => cross entropy : 1.9879483943192402
# (train) iter数 ： 176 => cross entropy : 1.998596957278875
#   (val) iter数 ： 176 => cross entropy : 2.1098393410454275
# (train) iter数 ： 177 => cross entropy : 2.086578047453047
#   (val) iter数 ： 177 => cross entropy : 2.0672168800460105
# (train) iter数 ： 178 => cross entropy : 1.982583557024762
#   (val) iter数 ： 178 => cross entropy : 1.9469896758420124
# (train) iter数 ： 179 => cross entropy : 1.9855933220643314
#   (val) iter数 ： 179 => cross entropy : 2.11996484052453
# (train) iter数 ： 180 => cross entropy : 1.9510885278242942
#   (val) iter数 ： 180 => cross entropy : 2.1324325500946473
# (train) iter数 ： 181 => cross entropy : 1.9821756221767182
#   (val) iter数 ： 181 => cross entropy : 2.1190694541635744
# (train) iter数 ： 182 => cross entropy : 1.8574218653777788
#   (val) iter数 ： 182 => cross entropy : 2.1180669674283927
# (train) iter数 ： 183 => cross entropy : 2.0848650095371433
#   (val) iter数 ： 183 => cross entropy : 2.044172728767473
# (train) iter数 ： 184 => cross entropy : 2.057315231641257
#   (val) iter数 ： 184 => cross entropy : 2.041403755584428
# (train) iter数 ： 185 => cross entropy : 2.032019432061842
#   (val) iter数 ： 185 => cross entropy : 2.060733626305392
# (train) iter数 ： 186 => cross entropy : 1.913759456212342
#   (val) iter数 ： 186 => cross entropy : 2.2474822256897697
# (train) iter数 ： 187 => cross entropy : 1.9995233146482922
#   (val) iter数 ： 187 => cross entropy : 2.015450757213958
# (train) iter数 ： 188 => cross entropy : 2.025067458277635
#   (val) iter数 ： 188 => cross entropy : 1.8944183734269135
# (train) iter数 ： 189 => cross entropy : 1.9917420423643877
#   (val) iter数 ： 189 => cross entropy : 1.9470632906003242
# (train) iter数 ： 190 => cross entropy : 1.974962225431407
#   (val) iter数 ： 190 => cross entropy : 1.8505504791239868
# (train) iter数 ： 191 => cross entropy : 1.9805052312980966
#   (val) iter数 ： 191 => cross entropy : 1.8622881742368709
# (train) iter数 ： 192 => cross entropy : 2.038028989467391
#   (val) iter数 ： 192 => cross entropy : 2.0352963299884395
# (train) iter数 ： 193 => cross entropy : 2.004302839223908
#   (val) iter数 ： 193 => cross entropy : 2.001877167178768
# (train) iter数 ： 194 => cross entropy : 1.9464896026557206
#   (val) iter数 ： 194 => cross entropy : 2.0865127924674383
# (train) iter数 ： 195 => cross entropy : 1.9874165730288724
#   (val) iter数 ： 195 => cross entropy : 1.9977926040674612
# (train) iter数 ： 196 => cross entropy : 2.020386155153261
#   (val) iter数 ： 196 => cross entropy : 2.1427305302505113
# (train) iter数 ： 197 => cross entropy : 2.073428765558866
#   (val) iter数 ： 197 => cross entropy : 2.1149199415391102
# (train) iter数 ： 198 => cross entropy : 1.9877171033835908
#   (val) iter数 ： 198 => cross entropy : 2.1134954775117807
# (train) iter数 ： 199 => cross entropy : 1.8911227451144068
#   (val) iter数 ： 199 => cross entropy : 2.0149247140005193
# (train) iter数 ： 200 => cross entropy : 2.0561579334738123
#   (val) iter数 ： 200 => cross entropy : 1.9394166743863481
# (train) iter数 ： 201 => cross entropy : 1.9821276351483617
#   (val) iter数 ： 201 => cross entropy : 2.100371203637426
# (train) iter数 ： 202 => cross entropy : 1.9815044079324218
#   (val) iter数 ： 202 => cross entropy : 1.9795801788490408
# (train) iter数 ： 203 => cross entropy : 1.9632738488381603
#   (val) iter数 ： 203 => cross entropy : 2.055610244303954
# (train) iter数 ： 204 => cross entropy : 1.9578104114964743
#   (val) iter数 ： 204 => cross entropy : 2.049726343314992
# (train) iter数 ： 205 => cross entropy : 2.01525536905785
#   (val) iter数 ： 205 => cross entropy : 2.0771909509502375
# (train) iter数 ： 206 => cross entropy : 1.9913456667699287
#   (val) iter数 ： 206 => cross entropy : 2.0751000626802143
# (train) iter数 ： 207 => cross entropy : 1.9033492995493173
#   (val) iter数 ： 207 => cross entropy : 1.9904349810293356
# (train) iter数 ： 208 => cross entropy : 1.980328318101947
#   (val) iter数 ： 208 => cross entropy : 2.0179516794241414
# (train) iter数 ： 209 => cross entropy : 1.9034619238238968
#   (val) iter数 ： 209 => cross entropy : 2.058199119577956
# (train) iter数 ： 210 => cross entropy : 1.9295483394305073
#   (val) iter数 ： 210 => cross entropy : 2.0090147726026055
# (train) iter数 ： 211 => cross entropy : 1.8907526203960097
#   (val) iter数 ： 211 => cross entropy : 2.057133070174753
# (train) iter数 ： 212 => cross entropy : 2.054225103756246
#   (val) iter数 ： 212 => cross entropy : 1.9821550876633212
# (train) iter数 ： 213 => cross entropy : 1.9044977107868761
#   (val) iter数 ： 213 => cross entropy : 2.117167003011571
# (train) iter数 ： 214 => cross entropy : 1.9843318298898875
#   (val) iter数 ： 214 => cross entropy : 2.0432199692341144
# (train) iter数 ： 215 => cross entropy : 1.8834615432451765
#   (val) iter数 ： 215 => cross entropy : 2.005377063129456
# (train) iter数 ： 216 => cross entropy : 2.0801311667435516
#   (val) iter数 ： 216 => cross entropy : 2.0677392215097745
# (train) iter数 ： 217 => cross entropy : 1.9110341645930822
#   (val) iter数 ： 217 => cross entropy : 1.9056262241365851
# (train) iter数 ： 218 => cross entropy : 2.013497198594132
#   (val) iter数 ： 218 => cross entropy : 1.9336294624680983
# (train) iter数 ： 219 => cross entropy : 1.952198496486776
#   (val) iter数 ： 219 => cross entropy : 1.9168492649084994
# (train) iter数 ： 220 => cross entropy : 2.0336263243049166
#   (val) iter数 ： 220 => cross entropy : 2.050309545503759
# (train) iter数 ： 221 => cross entropy : 2.000923208138278
#   (val) iter数 ： 221 => cross entropy : 1.9424290844960788
# (train) iter数 ： 222 => cross entropy : 1.912562970645368
#   (val) iter数 ： 222 => cross entropy : 2.093595791594425
# (train) iter数 ： 223 => cross entropy : 1.7467644817494978
#   (val) iter数 ： 223 => cross entropy : 2.0145419419767436
# (train) iter数 ： 224 => cross entropy : 2.088001678540791
#   (val) iter数 ： 224 => cross entropy : 1.944760428145461
# (train) iter数 ： 225 => cross entropy : 2.0020752833450506
#   (val) iter数 ： 225 => cross entropy : 1.9846898709167975
# (train) iter数 ： 226 => cross entropy : 1.9048668439656276
#   (val) iter数 ： 226 => cross entropy : 2.010958985786428
# (train) iter数 ： 227 => cross entropy : 1.9783296458985653
#   (val) iter数 ： 227 => cross entropy : 1.9709503115074938
# (train) iter数 ： 228 => cross entropy : 1.961858651161454
#   (val) iter数 ： 228 => cross entropy : 1.921017187069557
# (train) iter数 ： 229 => cross entropy : 2.054589516124083
#   (val) iter数 ： 229 => cross entropy : 1.9225914132509097
# (train) iter数 ： 230 => cross entropy : 1.997688227686831
#   (val) iter数 ： 230 => cross entropy : 1.9823546975478683
# (train) iter数 ： 231 => cross entropy : 1.9245330110100394
#   (val) iter数 ： 231 => cross entropy : 1.973258054963381
# (train) iter数 ： 232 => cross entropy : 1.936333211900406
#   (val) iter数 ： 232 => cross entropy : 1.9947540298230564
# (train) iter数 ： 233 => cross entropy : 1.9333242775317505
#   (val) iter数 ： 233 => cross entropy : 1.9470913756327062
# (train) iter数 ： 234 => cross entropy : 1.9832136814944528
#   (val) iter数 ： 234 => cross entropy : 1.9934879628769637
# (train) iter数 ： 235 => cross entropy : 1.8222687529653314
#   (val) iter数 ： 235 => cross entropy : 2.0820861256033973
# (train) iter数 ： 236 => cross entropy : 1.9692203311177137
#   (val) iter数 ： 236 => cross entropy : 2.022853839558102
# (train) iter数 ： 237 => cross entropy : 2.0021880862721555
#   (val) iter数 ： 237 => cross entropy : 1.8938748627032134
# (train) iter数 ： 238 => cross entropy : 2.0095043138622213
#   (val) iter数 ： 238 => cross entropy : 1.9385599338367734
# (train) iter数 ： 239 => cross entropy : 1.8639073658848027
#   (val) iter数 ： 239 => cross entropy : 1.8715977122899
# (train) iter数 ： 240 => cross entropy : 1.9669146725675057
#   (val) iter数 ： 240 => cross entropy : 1.9866856390338528
# (train) iter数 ： 241 => cross entropy : 1.8826826696980534
#   (val) iter数 ： 241 => cross entropy : 1.932071666152053
# (train) iter数 ： 242 => cross entropy : 1.9767290475522132
#   (val) iter数 ： 242 => cross entropy : 2.0236891650404343
# (train) iter数 ： 243 => cross entropy : 1.9750368525385307
#   (val) iter数 ： 243 => cross entropy : 2.1174581789523494
# (train) iter数 ： 244 => cross entropy : 2.0514243304821207
#   (val) iter数 ： 244 => cross entropy : 1.9766935555498089
# (train) iter数 ： 245 => cross entropy : 1.9145681177807743
#   (val) iter数 ： 245 => cross entropy : 1.9499076626151237
# (train) iter数 ： 246 => cross entropy : 1.905672256351873
#   (val) iter数 ： 246 => cross entropy : 1.9719851535803288
# (train) iter数 ： 247 => cross entropy : 1.9639139322323715
#   (val) iter数 ： 247 => cross entropy : 1.881199421429188
# (train) iter数 ： 248 => cross entropy : 1.898044710687401
#   (val) iter数 ： 248 => cross entropy : 2.0401022070403445
# (train) iter数 ： 249 => cross entropy : 1.7621274878518975
#   (val) iter数 ： 249 => cross entropy : 2.016156579141906
# (train) iter数 ： 250 => cross entropy : 1.906483749388693
#   (val) iter数 ： 250 => cross entropy : 1.9937861735329905
# (train) iter数 ： 251 => cross entropy : 1.9511948375209087
#   (val) iter数 ： 251 => cross entropy : 2.038583332780488
# (train) iter数 ： 252 => cross entropy : 1.8685869328164502
#   (val) iter数 ： 252 => cross entropy : 1.8842337401152158
# (train) iter数 ： 253 => cross entropy : 1.8768754509527932
#   (val) iter数 ： 253 => cross entropy : 2.017722594442542
# (train) iter数 ： 254 => cross entropy : 1.9316057557708115
#   (val) iter数 ： 254 => cross entropy : 1.9601508017998688
# (train) iter数 ： 255 => cross entropy : 1.9653218204981606
#   (val) iter数 ： 255 => cross entropy : 2.044507857261692
# (train) iter数 ： 256 => cross entropy : 1.8194334161611974
#   (val) iter数 ： 256 => cross entropy : 1.9675756686583232
# (train) iter数 ： 257 => cross entropy : 2.058888448055158
#   (val) iter数 ： 257 => cross entropy : 2.0182359184181444
# (train) iter数 ： 258 => cross entropy : 1.898106477022472
#   (val) iter数 ： 258 => cross entropy : 1.9994098464582408
# (train) iter数 ： 259 => cross entropy : 1.9807168096506382
#   (val) iter数 ： 259 => cross entropy : 1.9147039825313834
# (train) iter数 ： 260 => cross entropy : 1.695697016539634
#   (val) iter数 ： 260 => cross entropy : 2.163215863187481
# (train) iter数 ： 261 => cross entropy : 1.947337758176321
#   (val) iter数 ： 261 => cross entropy : 1.9477243138431957
# (train) iter数 ： 262 => cross entropy : 1.8636333361300323
#   (val) iter数 ： 262 => cross entropy : 2.0258574181952826
# (train) iter数 ： 263 => cross entropy : 1.9399530777005891
#   (val) iter数 ： 263 => cross entropy : 1.8153502370450392
# (train) iter数 ： 264 => cross entropy : 1.9021382302959777
#   (val) iter数 ： 264 => cross entropy : 1.8324371121412257
# (train) iter数 ： 265 => cross entropy : 1.9567163587082854
#   (val) iter数 ： 265 => cross entropy : 1.8432355225783845
# (train) iter数 ： 266 => cross entropy : 2.0470412601688572
#   (val) iter数 ： 266 => cross entropy : 1.9526177744627735
# (train) iter数 ： 267 => cross entropy : 1.9775676510870461
#   (val) iter数 ： 267 => cross entropy : 1.9880210632000663
# (train) iter数 ： 268 => cross entropy : 1.7680776957941107
#   (val) iter数 ： 268 => cross entropy : 1.9087364102677704
# (train) iter数 ： 269 => cross entropy : 1.9476080045239463
#   (val) iter数 ： 269 => cross entropy : 1.9269698525008694
# (train) iter数 ： 270 => cross entropy : 1.9105505773018472
#   (val) iter数 ： 270 => cross entropy : 1.8834708065286798
# (train) iter数 ： 271 => cross entropy : 1.9634791417710902
#   (val) iter数 ： 271 => cross entropy : 2.0499446748757957
# (train) iter数 ： 272 => cross entropy : 1.9450775650656214
#   (val) iter数 ： 272 => cross entropy : 1.924258841845613
# (train) iter数 ： 273 => cross entropy : 1.9914940088716435
#   (val) iter数 ： 273 => cross entropy : 1.8851270958856219
# (train) iter数 ： 274 => cross entropy : 1.9083217747665682
#   (val) iter数 ： 274 => cross entropy : 1.9953517120187385
# (train) iter数 ： 275 => cross entropy : 1.746218135698134
#   (val) iter数 ： 275 => cross entropy : 1.9027408842258227
# (train) iter数 ： 276 => cross entropy : 1.8487613654581674
#   (val) iter数 ： 276 => cross entropy : 1.8505276393512298
# (train) iter数 ： 277 => cross entropy : 1.8842128431243783
#   (val) iter数 ： 277 => cross entropy : 1.8966792046479122
# (train) iter数 ： 278 => cross entropy : 1.7625285246732618
#   (val) iter数 ： 278 => cross entropy : 2.0190100779434066
# (train) iter数 ： 279 => cross entropy : 2.093468682999306
#   (val) iter数 ： 279 => cross entropy : 2.0281538009353968
# (train) iter数 ： 280 => cross entropy : 1.9423368524104334
#   (val) iter数 ： 280 => cross entropy : 1.8681462347220035
# (train) iter数 ： 281 => cross entropy : 1.9972801724715312
#   (val) iter数 ： 281 => cross entropy : 2.025842199176874
# (train) iter数 ： 282 => cross entropy : 1.8360982957722856
#   (val) iter数 ： 282 => cross entropy : 1.9706229392394137
# (train) iter数 ： 283 => cross entropy : 1.925165284744007
#   (val) iter数 ： 283 => cross entropy : 2.032302592283749
# (train) iter数 ： 284 => cross entropy : 1.7724078032703532
#   (val) iter数 ： 284 => cross entropy : 1.7523370584073144
# (train) iter数 ： 285 => cross entropy : 1.8816358411502556
#   (val) iter数 ： 285 => cross entropy : 2.0088217378922986
# (train) iter数 ： 286 => cross entropy : 1.9069549924945335
#   (val) iter数 ： 286 => cross entropy : 1.8907304538251513
# (train) iter数 ： 287 => cross entropy : 1.9496799619016596
#   (val) iter数 ： 287 => cross entropy : 1.8564768722553169
# (train) iter数 ： 288 => cross entropy : 1.9959823428276913
#   (val) iter数 ： 288 => cross entropy : 2.025427760713226
# (train) iter数 ： 289 => cross entropy : 1.9150964704406968
#   (val) iter数 ： 289 => cross entropy : 1.9496922100175327
# (train) iter数 ： 290 => cross entropy : 2.0312824871465467
#   (val) iter数 ： 290 => cross entropy : 1.7874687403705556
# (train) iter数 ： 291 => cross entropy : 1.8353335133229671
#   (val) iter数 ： 291 => cross entropy : 2.0199587593501453
# (train) iter数 ： 292 => cross entropy : 1.9407344703105336
#   (val) iter数 ： 292 => cross entropy : 1.958862189674813
# (train) iter数 ： 293 => cross entropy : 1.9805541099443915
#   (val) iter数 ： 293 => cross entropy : 1.8744502074860223
# (train) iter数 ： 294 => cross entropy : 1.9104785176315773
#   (val) iter数 ： 294 => cross entropy : 1.9708804644460292
# (train) iter数 ： 295 => cross entropy : 1.7194732260482128
#   (val) iter数 ： 295 => cross entropy : 2.0220282145163346
# (train) iter数 ： 296 => cross entropy : 1.925635141547537
#   (val) iter数 ： 296 => cross entropy : 1.9340581717951317
# (train) iter数 ： 297 => cross entropy : 1.896119074898364
#   (val) iter数 ： 297 => cross entropy : 1.9679196879032526
# (train) iter数 ： 298 => cross entropy : 1.8976073551812018
#   (val) iter数 ： 298 => cross entropy : 1.9533281019676687
# (train) iter数 ： 299 => cross entropy : 1.9022957869185657
#   (val) iter数 ： 299 => cross entropy : 2.0041481148740483
# (train) iter数 ： 300 => cross entropy : 1.9454556645765948
#   (val) iter数 ： 300 => cross entropy : 2.1142709629771796
# (train) iter数 ： 301 => cross entropy : 1.8515595237318014
#   (val) iter数 ： 301 => cross entropy : 1.8509007985775208
# (train) iter数 ： 302 => cross entropy : 1.8528431974834305
#   (val) iter数 ： 302 => cross entropy : 1.904631109505231
# (train) iter数 ： 303 => cross entropy : 1.9524524298328914
#   (val) iter数 ： 303 => cross entropy : 1.9167303499390635
# (train) iter数 ： 304 => cross entropy : 1.7991546398196263
#   (val) iter数 ： 304 => cross entropy : 2.060940596686907
# (train) iter数 ： 305 => cross entropy : 1.9960237010594888
#   (val) iter数 ： 305 => cross entropy : 2.070440617320264
# (train) iter数 ： 306 => cross entropy : 1.8902087031290478
#   (val) iter数 ： 306 => cross entropy : 1.9297213251348837
# (train) iter数 ： 307 => cross entropy : 2.000167197684502
#   (val) iter数 ： 307 => cross entropy : 1.9048760337741717
# (train) iter数 ： 308 => cross entropy : 1.8406597495694372
#   (val) iter数 ： 308 => cross entropy : 1.8967380903848186
# (train) iter数 ： 309 => cross entropy : 2.029770170136712
#   (val) iter数 ： 309 => cross entropy : 1.757535028047859
# (train) iter数 ： 310 => cross entropy : 1.9334413124270207
#   (val) iter数 ： 310 => cross entropy : 1.9595252528670395
# (train) iter数 ： 311 => cross entropy : 1.8381143579973171
#   (val) iter数 ： 311 => cross entropy : 2.017421607391845
# (train) iter数 ： 312 => cross entropy : 1.896212063544853
#   (val) iter数 ： 312 => cross entropy : 1.836252566784384
# (train) iter数 ： 313 => cross entropy : 1.8179490744962885
#   (val) iter数 ： 313 => cross entropy : 1.919080772337769
# (train) iter数 ： 314 => cross entropy : 1.8350571832990774
#   (val) iter数 ： 314 => cross entropy : 1.8092128912773717
# (train) iter数 ： 315 => cross entropy : 1.8441949628229715
#   (val) iter数 ： 315 => cross entropy : 1.856749488581086
# (train) iter数 ： 316 => cross entropy : 1.787682318711962
#   (val) iter数 ： 316 => cross entropy : 1.9209279949283706
# (train) iter数 ： 317 => cross entropy : 1.9535401287366385
#   (val) iter数 ： 317 => cross entropy : 1.90860449483177
# (train) iter数 ： 318 => cross entropy : 1.833977028406668
#   (val) iter数 ： 318 => cross entropy : 1.9044555321048273
# (train) iter数 ： 319 => cross entropy : 1.7724419480744964
#   (val) iter数 ： 319 => cross entropy : 1.8665565468864764
# (train) iter数 ： 320 => cross entropy : 1.826042447047814
#   (val) iter数 ： 320 => cross entropy : 2.129748417793381
# (train) iter数 ： 321 => cross entropy : 1.729312220066383
#   (val) iter数 ： 321 => cross entropy : 1.9591853246699107
# (train) iter数 ： 322 => cross entropy : 1.8777815359117527
#   (val) iter数 ： 322 => cross entropy : 1.9905249131706733
# (train) iter数 ： 323 => cross entropy : 1.897489117386563
#   (val) iter数 ： 323 => cross entropy : 1.8813734510344373
# (train) iter数 ： 324 => cross entropy : 1.9443879025711466
#   (val) iter数 ： 324 => cross entropy : 1.9548515854084354
# (train) iter数 ： 325 => cross entropy : 1.7772204931656241
#   (val) iter数 ： 325 => cross entropy : 1.9780684177811272
# (train) iter数 ： 326 => cross entropy : 1.7890401344932514
#   (val) iter数 ： 326 => cross entropy : 1.993084608463403
# (train) iter数 ： 327 => cross entropy : 1.9159253916707328
#   (val) iter数 ： 327 => cross entropy : 1.8523336409243258
# (train) iter数 ： 328 => cross entropy : 1.860057787974533
#   (val) iter数 ： 328 => cross entropy : 1.9579400836180931
# (train) iter数 ： 329 => cross entropy : 1.8030293474758956
#   (val) iter数 ： 329 => cross entropy : 1.8506078321896091
# (train) iter数 ： 330 => cross entropy : 1.8116805767841822
#   (val) iter数 ： 330 => cross entropy : 1.9269304061239518
# (train) iter数 ： 331 => cross entropy : 1.8781479041389912
#   (val) iter数 ： 331 => cross entropy : 1.9224145359209204
# (train) iter数 ： 332 => cross entropy : 1.94143767615154
#   (val) iter数 ： 332 => cross entropy : 1.9532772195564456
# (train) iter数 ： 333 => cross entropy : 1.914023331674616
#   (val) iter数 ： 333 => cross entropy : 1.9124574983298839
# (train) iter数 ： 334 => cross entropy : 2.0354988105905476
#   (val) iter数 ： 334 => cross entropy : 1.9269282110950372
# (train) iter数 ： 335 => cross entropy : 1.8313984960235297
#   (val) iter数 ： 335 => cross entropy : 1.9223200790158694
# (train) iter数 ： 336 => cross entropy : 1.8060281158386466
#   (val) iter数 ： 336 => cross entropy : 1.9068313195003204
# (train) iter数 ： 337 => cross entropy : 1.8423052598281566
#   (val) iter数 ： 337 => cross entropy : 1.8535927035456627
# (train) iter数 ： 338 => cross entropy : 1.836680645764036
#   (val) iter数 ： 338 => cross entropy : 1.9363871870436828
# (train) iter数 ： 339 => cross entropy : 1.8205860793285062
#   (val) iter数 ： 339 => cross entropy : 1.8861264489766627
# (train) iter数 ： 340 => cross entropy : 1.787596319106337
#   (val) iter数 ： 340 => cross entropy : 1.9680965512176052
# (train) iter数 ： 341 => cross entropy : 1.9410481078859836
#   (val) iter数 ： 341 => cross entropy : 1.8398495951913127
# (train) iter数 ： 342 => cross entropy : 1.7668319173259552
#   (val) iter数 ： 342 => cross entropy : 1.773906360402198
# (train) iter数 ： 343 => cross entropy : 1.8526396734774022
#   (val) iter数 ： 343 => cross entropy : 1.8482986473239464
# (train) iter数 ： 344 => cross entropy : 1.740660825066081
#   (val) iter数 ： 344 => cross entropy : 2.0730508330030455
# (train) iter数 ： 345 => cross entropy : 1.7290231108083594
#   (val) iter数 ： 345 => cross entropy : 1.9144648505743866
# (train) iter数 ： 346 => cross entropy : 1.7193989068794324
#   (val) iter数 ： 346 => cross entropy : 1.9180396866925933
# (train) iter数 ： 347 => cross entropy : 1.9343648608764
#   (val) iter数 ： 347 => cross entropy : 1.82293994389008
# (train) iter数 ： 348 => cross entropy : 1.937668195508496
#   (val) iter数 ： 348 => cross entropy : 1.8705650183727123
# (train) iter数 ： 349 => cross entropy : 1.8202422621523426
#   (val) iter数 ： 349 => cross entropy : 1.9242181305819654
# (train) iter数 ： 350 => cross entropy : 1.9292165852647938
#   (val) iter数 ： 350 => cross entropy : 1.894020823908514
# (train) iter数 ： 351 => cross entropy : 1.8137084044988356
#   (val) iter数 ： 351 => cross entropy : 1.9385929221195584
# (train) iter数 ： 352 => cross entropy : 1.830955039177231
#   (val) iter数 ： 352 => cross entropy : 1.8720096805435409
# (train) iter数 ： 353 => cross entropy : 1.821895334391806
#   (val) iter数 ： 353 => cross entropy : 1.9683369953261167
# (train) iter数 ： 354 => cross entropy : 1.8140941430634703
#   (val) iter数 ： 354 => cross entropy : 1.8540055970761582
# (train) iter数 ： 355 => cross entropy : 1.8266066670756063
#   (val) iter数 ： 355 => cross entropy : 2.029163757721547
# (train) iter数 ： 356 => cross entropy : 1.8466384329995202
#   (val) iter数 ： 356 => cross entropy : 2.003077046918292
# (train) iter数 ： 357 => cross entropy : 1.9144558903309168
#   (val) iter数 ： 357 => cross entropy : 1.9591031528114087
# (train) iter数 ： 358 => cross entropy : 1.8330574185646165
#   (val) iter数 ： 358 => cross entropy : 1.9231914773851466
# (train) iter数 ： 359 => cross entropy : 1.8252744539345174
#   (val) iter数 ： 359 => cross entropy : 1.7380222684709352
# (train) iter数 ： 360 => cross entropy : 1.7737593085242562
#   (val) iter数 ： 360 => cross entropy : 1.828640239091498
# (train) iter数 ： 361 => cross entropy : 1.6599003047613161
#   (val) iter数 ： 361 => cross entropy : 1.8637397811830896
# (train) iter数 ： 362 => cross entropy : 1.9256917846127621
#   (val) iter数 ： 362 => cross entropy : 1.8325211934909256
# (train) iter数 ： 363 => cross entropy : 1.8292616883446564
#   (val) iter数 ： 363 => cross entropy : 1.7480212248750135
# (train) iter数 ： 364 => cross entropy : 1.7405853107697986
#   (val) iter数 ： 364 => cross entropy : 1.7386045214210708
# (train) iter数 ： 365 => cross entropy : 1.7143781415043131
#   (val) iter数 ： 365 => cross entropy : 1.8443566721418945
# (train) iter数 ： 366 => cross entropy : 1.7398658466669361
#   (val) iter数 ： 366 => cross entropy : 1.7008564062964167
# (train) iter数 ： 367 => cross entropy : 1.6012412036468395
#   (val) iter数 ： 367 => cross entropy : 1.8356862020754647
# (train) iter数 ： 368 => cross entropy : 1.7015785844467217
#   (val) iter数 ： 368 => cross entropy : 2.0323967112193233
# (train) iter数 ： 369 => cross entropy : 1.7183036841857502
#   (val) iter数 ： 369 => cross entropy : 1.7643473880229086
# (train) iter数 ： 370 => cross entropy : 1.7045297821360208
#   (val) iter数 ： 370 => cross entropy : 1.9220296083467774
# (train) iter数 ： 371 => cross entropy : 1.6916569048394636
#   (val) iter数 ： 371 => cross entropy : 1.8364228831036926
# (train) iter数 ： 372 => cross entropy : 1.746448071012325
#   (val) iter数 ： 372 => cross entropy : 1.6751078390435552
# (train) iter数 ： 373 => cross entropy : 1.6088788589673535
#   (val) iter数 ： 373 => cross entropy : 1.7332455517797614
# (train) iter数 ： 374 => cross entropy : 1.7323963207844995
#   (val) iter数 ： 374 => cross entropy : 1.8053793552077686
# (train) iter数 ： 375 => cross entropy : 1.6779979984304276
#   (val) iter数 ： 375 => cross entropy : 1.8971683673674518
# (train) iter数 ： 376 => cross entropy : 1.8780923619209273
#   (val) iter数 ： 376 => cross entropy : 1.700313780131397
# (train) iter数 ： 377 => cross entropy : 1.7767669996993822
#   (val) iter数 ： 377 => cross entropy : 1.9403504209624474
# (train) iter数 ： 378 => cross entropy : 1.8076701844923961
#   (val) iter数 ： 378 => cross entropy : 1.8456992785504178
# (train) iter数 ： 379 => cross entropy : 1.9904120666349898
#   (val) iter数 ： 379 => cross entropy : 2.3619974726982704
# (train) iter数 ： 380 => cross entropy : 2.3119257413155943
#   (val) iter数 ： 380 => cross entropy : 2.024864007641644
# (train) iter数 ： 381 => cross entropy : 1.765081742527746
#   (val) iter数 ： 381 => cross entropy : 1.9162026229661273
# (train) iter数 ： 382 => cross entropy : 1.8281016887553563
#   (val) iter数 ： 382 => cross entropy : 1.867053531474106
# (train) iter数 ： 383 => cross entropy : 1.8437467733003503
#   (val) iter数 ： 383 => cross entropy : 1.8551694105597343
# (train) iter数 ： 384 => cross entropy : 1.5131665221200286
#   (val) iter数 ： 384 => cross entropy : 1.697024679618843
# (train) iter数 ： 385 => cross entropy : 1.6973443088762872
#   (val) iter数 ： 385 => cross entropy : 1.6710540248137093
# (train) iter数 ： 386 => cross entropy : 1.647640131205003
#   (val) iter数 ： 386 => cross entropy : 1.750380631093721
# (train) iter数 ： 387 => cross entropy : 1.6635314112322996
#   (val) iter数 ： 387 => cross entropy : 1.8707565185343296
# (train) iter数 ： 388 => cross entropy : 2.1015130524925327
#   (val) iter数 ： 388 => cross entropy : 1.970384688956466
# (train) iter数 ： 389 => cross entropy : 1.606641807434677
#   (val) iter数 ： 389 => cross entropy : 1.8914706766344183
# (train) iter数 ： 390 => cross entropy : 1.6153671305345672
#   (val) iter数 ： 390 => cross entropy : 1.803012144437183
# (train) iter数 ： 391 => cross entropy : 1.5266407168074148
#   (val) iter数 ： 391 => cross entropy : 1.7000731714449182
# (train) iter数 ： 392 => cross entropy : 1.8066970993504072
#   (val) iter数 ： 392 => cross entropy : 2.029026213458772
# (train) iter数 ： 393 => cross entropy : 1.950344189795728
#   (val) iter数 ： 393 => cross entropy : 1.9577190767641384
# (train) iter数 ： 394 => cross entropy : 1.660117925444334
#   (val) iter数 ： 394 => cross entropy : 1.7894058754964748
# (train) iter数 ： 395 => cross entropy : 1.7181168961084172
#   (val) iter数 ： 395 => cross entropy : 1.6596608828527826
# (train) iter数 ： 396 => cross entropy : 1.6055645231729594
#   (val) iter数 ： 396 => cross entropy : 1.516693127431317
# (train) iter数 ： 397 => cross entropy : 1.5999618122424064
#   (val) iter数 ： 397 => cross entropy : 1.5606973239677986
# (train) iter数 ： 398 => cross entropy : 1.3887229309058409
#   (val) iter数 ： 398 => cross entropy : 1.5977685590159127
# (train) iter数 ： 399 => cross entropy : 1.9445902017927734
#   (val) iter数 ： 399 => cross entropy : 2.24532281418776
# (train) iter数 ： 400 => cross entropy : 1.6126259793455717
#   (val) iter数 ： 400 => cross entropy : 1.8605204555013686
# (train) iter数 ： 401 => cross entropy : 1.5745779376390452
#   (val) iter数 ： 401 => cross entropy : 1.607630148485805
# (train) iter数 ： 402 => cross entropy : 1.3929530252806488
#   (val) iter数 ： 402 => cross entropy : 1.5509919514954067
# (train) iter数 ： 403 => cross entropy : 1.366863341893463
#   (val) iter数 ： 403 => cross entropy : 1.4239485933072986
# (train) iter数 ： 404 => cross entropy : 1.3974540376907634
#   (val) iter数 ： 404 => cross entropy : 1.628274030595084
# (train) iter数 ： 405 => cross entropy : 1.4386066326837914
#   (val) iter数 ： 405 => cross entropy : 1.5614032387902275
# (train) iter数 ： 406 => cross entropy : 1.4600629010053956
#   (val) iter数 ： 406 => cross entropy : 1.400392911500071
# (train) iter数 ： 407 => cross entropy : 1.4843222690824227
#   (val) iter数 ： 407 => cross entropy : 1.4744282105531363
# (train) iter数 ： 408 => cross entropy : 1.6313740617621713
#   (val) iter数 ： 408 => cross entropy : 1.8619453041243723
# (train) iter数 ： 409 => cross entropy : 1.7033605170867998
#   (val) iter数 ： 409 => cross entropy : 1.7350128466491803
# (train) iter数 ： 410 => cross entropy : 1.665709044911245
#   (val) iter数 ： 410 => cross entropy : 1.4762213331646132
# (train) iter数 ： 411 => cross entropy : 1.218358853946324
#   (val) iter数 ： 411 => cross entropy : 1.3274002106993494
# (train) iter数 ： 412 => cross entropy : 1.1328350410899704
#   (val) iter数 ： 412 => cross entropy : 1.481348694662044
# (train) iter数 ： 413 => cross entropy : 1.3777343484419475
#   (val) iter数 ： 413 => cross entropy : 1.3422881562428473
# (train) iter数 ： 414 => cross entropy : 1.3036006772625557
#   (val) iter数 ： 414 => cross entropy : 1.5792220772375392
# (train) iter数 ： 415 => cross entropy : 1.9447931698514596
#   (val) iter数 ： 415 => cross entropy : 2.042254275026116
# (train) iter数 ： 416 => cross entropy : 1.4124962008171662
#   (val) iter数 ： 416 => cross entropy : 1.6028146927743927
# (train) iter数 ： 417 => cross entropy : 1.3348858663743002
#   (val) iter数 ： 417 => cross entropy : 1.6006998678873199
# (train) iter数 ： 418 => cross entropy : 1.3127997054112
#   (val) iter数 ： 418 => cross entropy : 1.4397204459031379
# ...
# (train) iter数 ： 465 => cross entropy : 0.07204899923000119
#   (val) iter数 ： 465 => cross entropy : 0.28589701201154705
# (train) iter数 ： 466 => cross entropy : 0.10740180262911153
#   (val) iter数 ： 466 => cross entropy : 0.2956504096678027
# (train) iter数 ： 467 => cross entropy : 0.1952267097474425
#   (val) iter数 ： 467 => cross entropy : 0.40964100824154165
# (train) iter数 ： 468 => cross entropy : 0.11760689960652089
#   (val) iter数 ： 468 => cross entropy : 0.1964656566484843
# (train) iter数 ： 469 => cross entropy : 0.2476263850007092
#   (val) iter数 ： 469 => cross entropy : 0.2157078331912537
# (train) iter数 ： 470 => cross entropy : 0.15080023303457876
#   (val) iter数 ： 470 => cross entropy : 0.15931154569606668
# (train) iter数 ： 471 => cross entropy : 0.11769112465304571
#   (val) iter数 ： 471 => cross entropy : 0.23247371318268142
# (train) iter数 ： 472 => cross entropy : 0.13120704354483534
#   (val) iter数 ： 472 => cross entropy : 0.33732280110116664
# (train) iter数 ： 473 => cross entropy : 0.209471807331241
#   (val) iter数 ： 473 => cross entropy : 0.2614214836900007
# (train) iter数 ： 474 => cross entropy : 0.2583599020884456
#   (val) iter数 ： 474 => cross entropy : 0.47262715204605166
# (train) iter数 ： 475 => cross entropy : 0.2512112748595654
#   (val) iter数 ： 475 => cross entropy : 0.47780198286932435
# (train) iter数 ： 476 => cross entropy : 0.10227072339766999
#   (val) iter数 ： 476 => cross entropy : 0.22471795061511637
# (train) iter数 ： 477 => cross entropy : 0.10740966077703812
#   (val) iter数 ： 477 => cross entropy : 0.2582572990981046
# (train) iter数 ： 478 => cross entropy : 0.13200746219355217
#   (val) iter数 ： 478 => cross entropy : 0.2993294579622426
# (train) iter数 ： 479 => cross entropy : 0.10402705863760744
#   (val) iter数 ： 479 => cross entropy : 0.16702277172343766
# (train) iter数 ： 480 => cross entropy : 0.07221110098809892
#   (val) iter数 ： 480 => cross entropy : 0.40368903051371974
# (train) iter数 ： 481 => cross entropy : 0.1968592771441877
#   (val) iter数 ： 481 => cross entropy : 0.2969875820639997
# (train) iter数 ： 482 => cross entropy : 0.17640157164177106
#   (val) iter数 ： 482 => cross entropy : 0.2714902739821632
# (train) iter数 ： 483 => cross entropy : 0.16506713713211454
#   (val) iter数 ： 483 => cross entropy : 0.2047718603855002
# (train) iter数 ： 484 => cross entropy : 0.3206593361141534
#   (val) iter数 ： 484 => cross entropy : 0.20884943772264897
# (train) iter数 ： 485 => cross entropy : 0.20291693882081915
#   (val) iter数 ： 485 => cross entropy : 0.45397139914538837
# (train) iter数 ： 486 => cross entropy : 0.26632038629163174
#   (val) iter数 ： 486 => cross entropy : 0.2158031879584916
# (train) iter数 ： 487 => cross entropy : 0.06156778443354785
#   (val) iter数 ： 487 => cross entropy : 0.327114332930882
# (train) iter数 ： 488 => cross entropy : 0.10356406341958568
#   (val) iter数 ： 488 => cross entropy : 0.26738589742313223
# (train) iter数 ： 489 => cross entropy : 0.15485964327139415
#   (val) iter数 ： 489 => cross entropy : 0.19552051996765063
# (train) iter数 ： 490 => cross entropy : 0.21966223067907198
#   (val) iter数 ： 490 => cross entropy : 0.4139704611364618
# (train) iter数 ： 491 => cross entropy : 0.15432930029324538
#   (val) iter数 ： 491 => cross entropy : 0.24822961203295138
# (train) iter数 ： 492 => cross entropy : 0.19875675633510737
#   (val) iter数 ： 492 => cross entropy : 0.22000251976495352
# (train) iter数 ： 493 => cross entropy : 0.08905028508450677
#   (val) iter数 ： 493 => cross entropy : 0.22099992642687108
# (train) iter数 ： 494 => cross entropy : 0.07859617861212262
#   (val) iter数 ： 494 => cross entropy : 0.2656224277705498
# (train) iter数 ： 495 => cross entropy : 0.17424402379931686
#   (val) iter数 ： 495 => cross entropy : 0.3084561881731783
# (train) iter数 ： 496 => cross entropy : 0.21245382194610293
#   (val) iter数 ： 496 => cross entropy : 0.12941347227763714
# (train) iter数 ： 497 => cross entropy : 0.15955058000039368
#   (val) iter数 ： 497 => cross entropy : 0.317427726582562
# (train) iter数 ： 498 => cross entropy : 0.2936997971514745
#   (val) iter数 ： 498 => cross entropy : 0.2732934429749925
# (train) iter数 ： 499 => cross entropy : 0.12217963194990047
#   (val) iter数 ： 499 => cross entropy : 0.3495971974545914
# (train) iter数 ： 500 => cross entropy : 0.1986033561536273
#   (val) iter数 ： 500 => cross entropy : 0.24392189920844426
# (train) iter数 ： 501 => cross entropy : 0.057919079396101664
#   (val) iter数 ： 501 => cross entropy : 0.1853931394903744
# (train) iter数 ： 502 => cross entropy : 0.1028259244962964
#   (val) iter数 ： 502 => cross entropy : 0.13091458468515868
# (train) iter数 ： 503 => cross entropy : 0.18516041229991828
#   (val) iter数 ： 503 => cross entropy : 0.2570168495899955
# (train) iter数 ： 504 => cross entropy : 0.12549976429032206
#   (val) iter数 ： 504 => cross entropy : 0.20592085590115344
# (train) iter数 ： 505 => cross entropy : 0.07301725428561366
#   (val) iter数 ： 505 => cross entropy : 0.11785737790436546
# (train) iter数 ： 506 => cross entropy : 0.19030235773180929
#   (val) iter数 ： 506 => cross entropy : 0.200659278691541
# (train) iter数 ： 507 => cross entropy : 0.09588295350626326
#   (val) iter数 ： 507 => cross entropy : 0.14784891751215176
# (train) iter数 ： 508 => cross entropy : 0.11487434076990755
#   (val) iter数 ： 508 => cross entropy : 0.3397681040468273
# (train) iter数 ： 509 => cross entropy : 0.16194048474904124
#   (val) iter数 ： 509 => cross entropy : 0.2969453102994925
# (train) iter数 ： 510 => cross entropy : 0.20652221164195594
#   (val) iter数 ： 510 => cross entropy : 0.16061481602293967
# (train) iter数 ： 511 => cross entropy : 0.19655581017142137
#   (val) iter数 ： 511 => cross entropy : 0.30862446492720297
# (train) iter数 ： 512 => cross entropy : 0.27538826981513376
#   (val) iter数 ： 512 => cross entropy : 0.2314938874727809
# (train) iter数 ： 513 => cross entropy : 0.100102244761415
#   (val) iter数 ： 513 => cross entropy : 0.23465524585437336
# (train) iter数 ： 514 => cross entropy : 0.10715383523171843
#   (val) iter数 ： 514 => cross entropy : 0.268373422442355
# (train) iter数 ： 515 => cross entropy : 0.3547601402858962
#   (val) iter数 ： 515 => cross entropy : 0.24465362614599961
# (train) iter数 ： 516 => cross entropy : 0.08528985380712462
#   (val) iter数 ： 516 => cross entropy : 0.22501374185471257
# (train) iter数 ： 517 => cross entropy : 0.17315525768554643
#   (val) iter数 ： 517 => cross entropy : 0.21178701001004363
# (train) iter数 ： 518 => cross entropy : 0.16467587914730397
#   (val) iter数 ： 518 => cross entropy : 0.21294280353504524
# (train) iter数 ： 519 => cross entropy : 0.060561842141015655
#   (val) iter数 ： 519 => cross entropy : 0.33771956978860357
# (train) iter数 ： 520 => cross entropy : 0.08035398925021839
#   (val) iter数 ： 520 => cross entropy : 0.17784773242806962
# (train) iter数 ： 521 => cross entropy : 0.15620406873139894
#   (val) iter数 ： 521 => cross entropy : 0.21534246219595926
# (train) iter数 ： 522 => cross entropy : 0.14095591306586905
#   (val) iter数 ： 522 => cross entropy : 0.3467001608816173
# (train) iter数 ： 523 => cross entropy : 0.04702564687442487
#   (val) iter数 ： 523 => cross entropy : 0.11024046231927805
# (train) iter数 ： 524 => cross entropy : 0.32541162137574975
#   (val) iter数 ： 524 => cross entropy : 0.2398753863425249
# (train) iter数 ： 525 => cross entropy : 0.30750318503316504
#   (val) iter数 ： 525 => cross entropy : 0.24785023067510661
# (train) iter数 ： 526 => cross entropy : 0.22656844425820408
#   (val) iter数 ： 526 => cross entropy : 0.3315393519608119
# (train) iter数 ： 527 => cross entropy : 0.11989153749465303
#   (val) iter数 ： 527 => cross entropy : 0.1899526527314368
# (train) iter数 ： 528 => cross entropy : 0.08600615279307809
#   (val) iter数 ： 528 => cross entropy : 0.22384384931791665
# (train) iter数 ： 529 => cross entropy : 0.07491510087606022
#   (val) iter数 ： 529 => cross entropy : 0.1399175082578302
# (train) iter数 ： 530 => cross entropy : 0.19115571144844457
#   (val) iter数 ： 530 => cross entropy : 0.26342297373797713
# (train) iter数 ： 531 => cross entropy : 0.4274401086616356
#   (val) iter数 ： 531 => cross entropy : 0.4342166651579653
# (train) iter数 ： 532 => cross entropy : 0.1519505498069179
#   (val) iter数 ： 532 => cross entropy : 0.4688723465018253
# (train) iter数 ： 533 => cross entropy : 0.22344654010489073
#   (val) iter数 ： 533 => cross entropy : 0.14912102811259267
# (train) iter数 ： 534 => cross entropy : 0.10973277504793183
#   (val) iter数 ： 534 => cross entropy : 0.267679463578162
# (train) iter数 ： 535 => cross entropy : 0.10072862357958777
#   (val) iter数 ： 535 => cross entropy : 0.2493143646039382
# (train) iter数 ： 536 => cross entropy : 0.1801564987186169
#   (val) iter数 ： 536 => cross entropy : 0.4378791554950023
# (train) iter数 ： 537 => cross entropy : 0.1766528787095233
#   (val) iter数 ： 537 => cross entropy : 0.20144860300249473
# (train) iter数 ： 538 => cross entropy : 0.0905485089309551
#   (val) iter数 ： 538 => cross entropy : 0.24302507007014185
# (train) iter数 ： 539 => cross entropy : 0.12234889716382882
#   (val) iter数 ： 539 => cross entropy : 0.15371899470154643
# (train) iter数 ： 540 => cross entropy : 0.14381358012573894
#   (val) iter数 ： 540 => cross entropy : 0.2540818998368776
# (train) iter数 ： 541 => cross entropy : 0.07270678398200102
#   (val) iter数 ： 541 => cross entropy : 0.33053590754351564
# (train) iter数 ： 542 => cross entropy : 0.04941666029299058
#   (val) iter数 ： 542 => cross entropy : 0.20469608571234962
# (train) iter数 ： 543 => cross entropy : 0.22908780417284672
#   (val) iter数 ： 543 => cross entropy : 0.3122561827456603
# (train) iter数 ： 544 => cross entropy : 0.18252024016240875
#   (val) iter数 ： 544 => cross entropy : 0.31884543322955006
# (train) iter数 ： 545 => cross entropy : 0.11545802870152487
#   (val) iter数 ： 545 => cross entropy : 0.27616245972289194
# (train) iter数 ： 546 => cross entropy : 0.07380162725136954
#   (val) iter数 ： 546 => cross entropy : 0.4614156740488302
# (train) iter数 ： 547 => cross entropy : 0.08879685051553028
#   (val) iter数 ： 547 => cross entropy : 0.2880086167405831
# (train) iter数 ： 548 => cross entropy : 0.12843936330945424
#   (val) iter数 ： 548 => cross entropy : 0.5183609225505427
# (train) iter数 ： 549 => cross entropy : 0.16104981908028124
#   (val) iter数 ： 549 => cross entropy : 0.15622840361874543
# (train) iter数 ： 550 => cross entropy : 0.2649298064374463
#   (val) iter数 ： 550 => cross entropy : 0.15663212423176132
# (train) iter数 ： 551 => cross entropy : 0.16336403198265775
#   (val) iter数 ： 551 => cross entropy : 0.1810440001589242
# (train) iter数 ： 552 => cross entropy : 0.15392241915668983
#   (val) iter数 ： 552 => cross entropy : 0.31466559432504404
# (train) iter数 ： 553 => cross entropy : 0.12773129688291315
#   (val) iter数 ： 553 => cross entropy : 0.2831539947627481
# (train) iter数 ： 554 => cross entropy : 0.06974672476041303
#   (val) iter数 ： 554 => cross entropy : 0.1646319901314452
# (train) iter数 ： 555 => cross entropy : 0.2606495819299928
#   (val) iter数 ： 555 => cross entropy : 0.32056934440387946
# (train) iter数 ： 556 => cross entropy : 0.26778390745947567
#   (val) iter数 ： 556 => cross entropy : 0.20507846875618416
# (train) iter数 ： 557 => cross entropy : 0.10727390278910152
#   (val) iter数 ： 557 => cross entropy : 0.26868633260184377
# (train) iter数 ： 558 => cross entropy : 0.2917321791782926
#   (val) iter数 ： 558 => cross entropy : 0.1272978775092318
# (train) iter数 ： 559 => cross entropy : 0.22075950287649526
#   (val) iter数 ： 559 => cross entropy : 0.3935064344254665
# (train) iter数 ： 560 => cross entropy : 0.15676166320351007
#   (val) iter数 ： 560 => cross entropy : 0.35157309447769536
# (train) iter数 ： 561 => cross entropy : 0.238482739394034
#   (val) iter数 ： 561 => cross entropy : 0.34109151484582245
# (train) iter数 ： 562 => cross entropy : 0.27375955168071364
#   (val) iter数 ： 562 => cross entropy : 0.14956175290503443
# (train) iter数 ： 563 => cross entropy : 0.12721764431553
#   (val) iter数 ： 563 => cross entropy : 0.19390197519522911
# (train) iter数 ： 564 => cross entropy : 0.11371184773591952
#   (val) iter数 ： 564 => cross entropy : 0.32518983924180134
# (train) iter数 ： 565 => cross entropy : 0.06540584429423923
#   (val) iter数 ： 565 => cross entropy : 0.33219069812760504
# (train) iter数 ： 566 => cross entropy : 0.2999768124434469
#   (val) iter数 ： 566 => cross entropy : 0.31235153732440485
# (train) iter数 ： 567 => cross entropy : 0.10603318592939232
#   (val) iter数 ： 567 => cross entropy : 0.09125441293066142
# (train) iter数 ： 568 => cross entropy : 0.0947073960303249
#   (val) iter数 ： 568 => cross entropy : 0.17724220583030062
# (train) iter数 ： 569 => cross entropy : 0.13452669812586124
#   (val) iter数 ： 569 => cross entropy : 0.16979360635675056
# (train) iter数 ： 570 => cross entropy : 0.13960484395295447
#   (val) iter数 ： 570 => cross entropy : 0.40448766070861875
# (train) iter数 ： 571 => cross entropy : 0.12757470129969067
#   (val) iter数 ： 571 => cross entropy : 0.3826179227484571
# (train) iter数 ： 572 => cross entropy : 0.1550383015103333
#   (val) iter数 ： 572 => cross entropy : 0.1454383460782009
# (train) iter数 ： 573 => cross entropy : 0.10394258734729037
#   (val) iter数 ： 573 => cross entropy : 0.29502737323513045
# (train) iter数 ： 574 => cross entropy : 0.18883318475395108
#   (val) iter数 ： 574 => cross entropy : 0.2729185092288846
# (train) iter数 ： 575 => cross entropy : 0.10027790025247643
#   (val) iter数 ： 575 => cross entropy : 0.2570871160583163
# (train) iter数 ： 576 => cross entropy : 0.24863086014380978
#   (val) iter数 ： 576 => cross entropy : 0.22982532719728388
# (train) iter数 ： 577 => cross entropy : 0.1117763039287524
#   (val) iter数 ： 577 => cross entropy : 0.2822538242718956
# (train) iter数 ： 578 => cross entropy : 0.10631337835066801
#   (val) iter数 ： 578 => cross entropy : 0.24967077870541798
# (train) iter数 ： 579 => cross entropy : 0.1580665799883937
#   (val) iter数 ： 579 => cross entropy : 0.31950640347497705
# (train) iter数 ： 580 => cross entropy : 0.14748119705487966
#   (val) iter数 ： 580 => cross entropy : 0.24337940916256426
# (train) iter数 ： 581 => cross entropy : 0.11716383427970883
#   (val) iter数 ： 581 => cross entropy : 0.2183343022401751
# (train) iter数 ： 582 => cross entropy : 0.07073442876303636
#   (val) iter数 ： 582 => cross entropy : 0.2732483976350268
# (train) iter数 ： 583 => cross entropy : 0.12425721512420994
#   (val) iter数 ： 583 => cross entropy : 0.24878485791954194
# (train) iter数 ： 584 => cross entropy : 0.2349927499359372
#   (val) iter数 ： 584 => cross entropy : 0.44416874783764115
# (train) iter数 ： 585 => cross entropy : 0.11771886424341833
#   (val) iter数 ： 585 => cross entropy : 0.34751741716377343
# (train) iter数 ： 586 => cross entropy : 0.12337940508190388
#   (val) iter数 ： 586 => cross entropy : 0.33968672770054237
# (train) iter数 ： 587 => cross entropy : 0.07050872006064178
#   (val) iter数 ： 587 => cross entropy : 0.26963131283415465
# (train) iter数 ： 588 => cross entropy : 0.22552275093386953
#   (val) iter数 ： 588 => cross entropy : 0.27830338529591037
# (train) iter数 ： 589 => cross entropy : 0.13750713882094048
#   (val) iter数 ： 589 => cross entropy : 0.3125706178574024
# (train) iter数 ： 590 => cross entropy : 0.06669895025490896
#   (val) iter数 ： 590 => cross entropy : 0.11422408710024695
# (train) iter数 ： 591 => cross entropy : 0.16692327616048475
#   (val) iter数 ： 591 => cross entropy : 0.22684080115821015
# (train) iter数 ： 592 => cross entropy : 0.06401275142272356
#   (val) iter数 ： 592 => cross entropy : 0.17047800742946717
# (train) iter数 ： 593 => cross entropy : 0.2536658643298399
#   (val) iter数 ： 593 => cross entropy : 0.12855741681034338
# (train) iter数 ： 594 => cross entropy : 0.1563985951279357
#   (val) iter数 ： 594 => cross entropy : 0.17263933114508545
# (train) iter数 ： 595 => cross entropy : 0.11564308633681711
#   (val) iter数 ： 595 => cross entropy : 0.2501301705080017
# (train) iter数 ： 596 => cross entropy : 0.10923624020103875
#   (val) iter数 ： 596 => cross entropy : 0.4114585633181885
# (train) iter数 ： 597 => cross entropy : 0.1368162520051784
#   (val) iter数 ： 597 => cross entropy : 0.16996007863842294
# (train) iter数 ： 598 => cross entropy : 0.13148672895032384
#   (val) iter数 ： 598 => cross entropy : 0.2057530373599728
# (train) iter数 ： 599 => cross entropy : 0.13487430793846383
#   (val) iter数 ： 599 => cross entropy : 0.1275630479804836
# (train) iter数 ： 600 => cross entropy : 0.06424686457212726
#   (val) iter数 ： 600 => cross entropy : 0.27634870930346106

# %%
# 予測
y_pred = model_1.predict(X_val)[0]

# %%
# onehot化していたのでラベルに直す
y_val = np.argmax(y_val, axis=1)

# %%
# 正解率
accuracy_score(y_val,y_pred)
# Out:
# 0.9325833333333333

# %% [markdown]
# ### 【問題7】学習曲線のプロット
# 学習曲線をプロットしてください。
#
#
# ニューラルネットワークは過学習が発生しやすいため、学習曲線の確認が重要です。訓練データと検証データに対するエポックごとの損失（交差エントロピー誤差）を記録できるようにする必要があります。

# %%
plt.plot(model_1.L_log,label="train")
plt.plot(model_1.L_val_log,label="val")
plt.xlabel("iter")
plt.ylabel("cross entropy")
plt.legend()

# %% [markdown]
# 今回では、バッチサイズ80で600iterを1エポックとし２エポック学習した。結果、上記グラフの通り、train,valデータ共にcross entropyが低くなり、適切に学習させる事ができた。
# 600iter(1エポックに相当)である程度下り、あとは飽和しているため、600iter(1エポックに相当)はデータ48000データを学習させればある程度学習させ適切な予測ができると考えられる。
# 今回はラベル10個（0〜9）なので1ラベルあたり4800で約5000個あれば事足りると思われる。
# （このデータセットもこのディープラーニングの学習を見越して適切な枚数のデータを用意しているを推定）

# %% [markdown]
# ### 【問題8】（アドバンス課題）誤分類の確認
# 誤分類した画像はどのようなものだったかを確認してください。推定値を用意し、以下のコードを実行してください。

# %%
"""
語分類結果を並べて表示する。画像の上の表示は「推定結果/正解」である。

Parameters:
----------
y_pred : 推定値のndarray (n_samples,)
y_val : 検証データの正解ラベル(n_samples,)
X_val : 検証データの特徴量（n_samples, n_features)
"""
import numpy as np
import matplotlib.pyplot as plt
num = 36 # いくつ表示するか
true_false = y_pred==y_val
false_list = np.where(true_false==False)[0].astype(np.int)
if false_list.shape[0] < num:
    num = false_list.shape[0]
fig = plt.figure(figsize=(6, 6))
fig.subplots_adjust(left=0, right=0.8,  bottom=0, top=0.8, hspace=1, wspace=0.5)
for i in range(num):
    ax = fig.add_subplot(6, 6, i + 1, xticks=[], yticks=[])
    ax.set_title("{} / {}".format(y_pred[false_list[i]],y_val[false_list[i]]))
    ax.imshow(X_val.reshape(-1,28,28)[false_list[i]], cmap='gray')

# %%
# 正解ラベル：３、予測（確率が最も高い）：２　の予測確率分布の事例
true_false = y_pred!=y_val
plt.bar([i for i in range(10)], pred[1][true_false][4])
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# 予測が間違っているデータ（文字）を確認すると、例えば　”０と９”の共にマルがあるもの　や　”２と７”のようになんとなく形が似ているものである。これらは予測確率を見ると、確かに正解ラベルにもある程度予測の確率はでているが、それ以上に他の間違いやすいラベルに最も高い確率を返している事がわかった。（上記に一事例表示）
# 機械学習エンジニアは、このような間違いやすい傾向を把握すると共にこの間違いやすい場合にも適切に予測できるアルゴリズムを考えることも必要になってくると考える。
